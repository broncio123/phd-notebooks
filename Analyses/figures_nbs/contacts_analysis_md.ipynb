# %%
import numpy as np
import MDAnalysis as mda
from MDAnalysis.analysis.hydrogenbonds.hbond_analysis import HydrogenBondAnalysis

# %%
workdir = "data/cWza-S355C_conformation1_0050/"
u = mda.Universe(workdir+'md_100ns.tpr', workdir+'md_100ns.xtc',in_memory=True)
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.

# %%
# Check segments IDs
u.atoms.segments
list(u.atoms.segments)
# Out:
# [<Segment seg_0_Protein_chain_A>,
#  <Segment seg_10_K>,
#  <Segment seg_11_CL>,
#  <Segment seg_1_Protein_chain_B>,
#  <Segment seg_2_Protein_chain_C>,
#  <Segment seg_3_Protein_chain_D>,
#  <Segment seg_4_Protein_chain_E>,
#  <Segment seg_5_Protein_chain_F>,
#  <Segment seg_6_Protein_chain_G>,
#  <Segment seg_7_Protein_chain_H>,
#  <Segment seg_8_POPC>,
#  <Segment seg_9_SOL>]

# %% [raw]
# hbonds = HydrogenBondAnalysis(universe=u)
#
# protein_hydrogens_sel = hbonds.guess_hydrogens("protein")
# protein_acceptors_sel = hbonds.guess_acceptors("protein")
# hbonds.hydrogens_sel = f"not backbone and segid seg_0_Protein_chain_A"
# hbonds.acceptors_sel = f"not backbone and segid seg_1_Protein_chain_B"
#
# hbonds.run()

# %%
hbonds = HydrogenBondAnalysis(universe=u)

protein_hydrogens_sel = hbonds.guess_hydrogens("protein")
protein_acceptors_sel = hbonds.guess_acceptors("protein")
hbonds.hydrogens_sel = f"not backbone and segid seg_0_Protein_chain_A"
hbonds.acceptors_sel = f"not backbone and segid seg_1_Protein_chain_B"
hbonds.run()

# %% [markdown]
# * Filter by type, select the top 16
# * Filter IDs accoridng to type

# %%
hbond_counting_raw = hbonds.count_by_type()
hbond_counting_sorted = sorted(hbond_counting_raw, key=lambda x: int(x[-1]), reverse=True)
hbond_counting_sorted
# Out:
# /homes/sanjuan/.local/lib/python3.8/site-packages/MDAnalysis/analysis/hydrogenbonds/hbond_analysis.py:662: DeprecationWarning: The `hbonds` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.hbonds` instead.
#   warnings.warn(wmsg, DeprecationWarning)
# [array(['VAL:opls_135', 'VAL:opls_140', '22218'], dtype='<U21'),
#  array(['ILE:opls_135', 'ILE:opls_140', '19202'], dtype='<U21'),
#  array(['LEU:opls_135', 'LEU:opls_140', '17892'], dtype='<U21'),
#  array(['THR:opls_135', 'THR:opls_140', '11665'], dtype='<U21'),
#  array(['VAL:opls_137', 'VAL:opls_135', '9985'], dtype='<U21'),
#  array(['ARG:opls_300', 'ARG:opls_301', '9881'], dtype='<U21'),
#  array(['PRO:opls_136', 'PRO:opls_140', '7694'], dtype='<U21'),
#  array(['TRP:opls_145', 'TRP:opls_146', '7581'], dtype='<U21'),
#  array(['LEU:opls_137', 'LEU:opls_135', '7109'], dtype='<U21'),
#  array(['LYS:opls_136', 'LYS:opls_140', '6832'], dtype='<U21'),
#  array(['THR:opls_224B', 'THR:opls_140', '6699'], dtype='<U21'),
#  array(['VAL:opls_224B', 'VAL:opls_140', '6582'], dtype='<U21'),
#  array(['ARG:opls_308', 'ARG:opls_140', '6180'], dtype='<U21'),
#  array(['LEU:opls_136', 'LEU:opls_140', '5682'], dtype='<U21'),
#  array(['LEU:opls_224B', 'LEU:opls_140', '5563'], dtype='<U21'),
#  array(['THR:opls_158', 'THR:opls_140', '5164'], dtype='<U21'),
#  array(['GLN:opls_136', 'GLN:opls_140', '4816'], dtype='<U21'),
#  array(['TYR:opls_145', 'TYR:opls_146', '4752'], dtype='<U21'),
#  array(['ILE:opls_136', 'ILE:opls_140', '4736'], dtype='<U21'),
#  array(['TRP:opls_145', 'TRP:opls_145', '4642'], dtype='<U21'),
#  array(['VAL:opls_137', 'VAL:opls_140', '4637'], dtype='<U21'),
#  array(['ILE:opls_137', 'ILE:opls_135', '4596'], dtype='<U21'),
#  array(['TYR:opls_145', 'TYR:opls_145', '4567'], dtype='<U21'),
#  array(['ILE:opls_224B', 'ILE:opls_137', '4309'], dtype='<U21'),
#  array(['ILE:opls_224B', 'ILE:opls_140', '4277'], dtype='<U21'),
#  array(['ARG:opls_136', 'ARG:opls_140', '4144'], dtype='<U21'),
#  array(['ARG:opls_307', 'ARG:opls_140', '4064'], dtype='<U21'),
#  array(['ILE:opls_136', 'ILE:opls_135', '3938'], dtype='<U21'),
#  array(['ARG:opls_224B', 'ARG:opls_140', '3837'], dtype='<U21'),
#  array(['ARG:opls_303', 'ARG:opls_304', '3750'], dtype='<U21'),
#  array(['LYS:opls_287', 'LYS:opls_290', '3433'], dtype='<U21'),
#  array(['ARG:opls_300', 'ASP:opls_272', '3259'], dtype='<U21'),
#  array(['THR:opls_158', 'THR:opls_154', '3172'], dtype='<U21'),
#  array(['LEU:opls_224B', 'LEU:opls_136', '3109'], dtype='<U21'),
#  array(['THR:opls_158', 'THR:opls_135', '3076'], dtype='<U21'),
#  array(['HIS:opls_503', 'ASP:opls_272', '3011'], dtype='<U21'),
#  array(['ALA:opls_135', 'ALA:opls_140', '3003'], dtype='<U21'),
#  array(['LEU:opls_136', 'LEU:opls_137', '2872'], dtype='<U21'),
#  array(['ASP:opls_271', 'ASP:opls_272', '2827'], dtype='<U21'),
#  array(['ARG:opls_302', 'ARG:opls_300', '2826'], dtype='<U21'),
#  array(['TRP:opls_136', 'TRP:opls_140', '2811'], dtype='<U21'),
#  array(['ASN:opls_237', 'ASN:opls_240', '2598'], dtype='<U21'),
#  array(['ASN:opls_136', 'ASN:opls_235', '2591'], dtype='<U21'),
#  array(['TRP:opls_501', 'TRP:opls_145', '2570'], dtype='<U21'),
#  array(['CYS:opls_206', 'CYS:opls_140', '2565'], dtype='<U21'),
#  array(['PRO:opls_245', 'PRO:opls_140', '2550'], dtype='<U21'),
#  array(['THR:opls_271', 'THR:opls_272', '2506'], dtype='<U21'),
#  array(['PRO:opls_246', 'PRO:opls_136', '2455'], dtype='<U21'),
#  array(['TYR:opls_167', 'GLU:opls_272', '2347'], dtype='<U21'),
#  array(['TYR:opls_149', 'TYR:opls_140', '2331'], dtype='<U21'),
#  array(['LYS:opls_292', 'LYS:opls_140', '2200'], dtype='<U21'),
#  array(['ALA:opls_293B', 'ALA:opls_135', '2192'], dtype='<U21'),
#  array(['CYS:opls_224B', 'CYS:opls_140', '2149'], dtype='<U21'),
#  array(['HIS:opls_505', 'HIS:opls_140', '2088'], dtype='<U21'),
#  array(['ASP:opls_224B', 'ASP:opls_140', '2079'], dtype='<U21'),
#  array(['TRP:opls_502', 'TRP:opls_145', '2051'], dtype='<U21'),
#  array(['LYS:opls_136', 'LYS:opls_136', '2048'], dtype='<U21'),
#  array(['PRO:opls_246', 'PRO:opls_140', '1995'], dtype='<U21'),
#  array(['GLU:opls_274', 'GLU:opls_140', '1934'], dtype='<U21'),
#  array(['ALA:opls_287', 'ALA:opls_290', '1924'], dtype='<U21'),
#  array(['TRP:opls_500', 'TRP:opls_501', '1896'], dtype='<U21'),
#  array(['GLY:opls_223B', 'GLY:opls_140', '1862'], dtype='<U21'),
#  array(['TYR:opls_224B', 'TYR:opls_140', '1825'], dtype='<U21'),
#  array(['LEU:opls_137', 'LEU:opls_140', '1795'], dtype='<U21'),
#  array(['THR:opls_283', 'THR:opls_140', '1749'], dtype='<U21'),
#  array(['VAL:opls_224B', 'VAL:opls_137', '1695'], dtype='<U21'),
#  array(['HIS:opls_224B', 'HIS:opls_140', '1629'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLU:opls_272', '1619'], dtype='<U21'),
#  array(['THR:opls_238', 'THR:opls_241', '1606'], dtype='<U21'),
#  array(['TRP:opls_514', 'TRP:opls_503', '1570'], dtype='<U21'),
#  array(['GLU:opls_271', 'GLU:opls_272', '1490'], dtype='<U21'),
#  array(['TYR:opls_145', 'TYR:opls_166', '1482'], dtype='<U21'),
#  array(['HIS:opls_507', 'HIS:opls_146', '1466'], dtype='<U21'),
#  array(['ARG:opls_308', 'ARG:opls_307', '1452'], dtype='<U21'),
#  array(['GLU:opls_136', 'GLU:opls_274', '1439'], dtype='<U21'),
#  array(['THR:opls_224B', 'THR:opls_158', '1365'], dtype='<U21'),
#  array(['ASP:opls_274', 'ASP:opls_271', '1323'], dtype='<U21'),
#  array(['ASN:opls_224B', 'ASN:opls_136', '1300'], dtype='<U21'),
#  array(['CYS:opls_200', 'CYS:opls_204', '1297'], dtype='<U21'),
#  array(['ARG:opls_224B', 'ARG:opls_136', '1290'], dtype='<U21'),
#  array(['ASN:opls_136', 'ASN:opls_140', '1286'], dtype='<U21'),
#  array(['TYR:opls_166', 'TYR:opls_167', '1280'], dtype='<U21'),
#  array(['TYR:opls_149', 'TYR:opls_145', '1275'], dtype='<U21'),
#  array(['ARG:opls_307', 'ARG:opls_303', '1270'], dtype='<U21'),
#  array(['ILE:opls_137', 'ILE:opls_140', '1254'], dtype='<U21'),
#  array(['GLU:opls_224B', 'GLU:opls_140', '1227'], dtype='<U21'),
#  array(['TRP:opls_224B', 'TRP:opls_136', '1218'], dtype='<U21'),
#  array(['ILE:opls_137', 'ILE:opls_136', '1183'], dtype='<U21'),
#  array(['HIS:opls_503', 'HIS:opls_504', '1180'], dtype='<U21'),
#  array(['TRP:opls_136', 'TRP:opls_500', '1173'], dtype='<U21'),
#  array(['LYS:opls_224B', 'LYS:opls_140', '1134'], dtype='<U21'),
#  array(['VAL:opls_238', 'VAL:opls_241', '1119'], dtype='<U21'),
#  array(['LYS:opls_292', 'LYS:opls_287', '1100'], dtype='<U21'),
#  array(['GLU:opls_136', 'GLU:opls_140', '1091'], dtype='<U21'),
#  array(['PRO:opls_239', 'PRO:opls_245', '1088'], dtype='<U21'),
#  array(['GLU:opls_274', 'GLU:opls_271', '1070'], dtype='<U21'),
#  array(['LYS:opls_224B', 'LYS:opls_136', '1043'], dtype='<U21'),
#  array(['LYS:opls_136', 'LYS:opls_292', '999'], dtype='<U21'),
#  array(['HIS:opls_508', 'HIS:opls_503', '996'], dtype='<U21'),
#  array(['ASN:opls_224B', 'ASN:opls_140', '987'], dtype='<U21'),
#  array(['ARG:opls_303', 'GLU:opls_272', '951'], dtype='<U21'),
#  array(['THR:opls_154', 'ASN:opls_236', '933'], dtype='<U21'),
#  array(['HIS:opls_506', 'HIS:opls_146', '910'], dtype='<U21'),
#  array(['TRP:opls_501', 'TRP:opls_502', '905'], dtype='<U21'),
#  array(['GLN:opls_224B', 'GLN:opls_140', '904'], dtype='<U21'),
#  array(['ARG:opls_303', 'ARG:opls_302', '879'], dtype='<U21'),
#  array(['GLN:opls_237', 'GLN:opls_240', '847'], dtype='<U21'),
#  array(['ARG:opls_136', 'ARG:opls_308', '826'], dtype='<U21'),
#  array(['ASN:opls_235', 'ASN:opls_236', '797'], dtype='<U21'),
#  array(['TYR:opls_238', 'TYR:opls_241', '794'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_154', '782'], dtype='<U21'),
#  array(['TRP:opls_238', 'TRP:opls_241', '779'], dtype='<U21'),
#  array(['LYS:opls_238', 'LYS:opls_241', '766'], dtype='<U21'),
#  array(['ALA:opls_293B', 'ALA:opls_140', '749'], dtype='<U21'),
#  array(['THR:opls_283', 'THR:opls_158', '737'], dtype='<U21'),
#  array(['ASN:opls_237', 'GLN:opls_236', '692'], dtype='<U21'),
#  array(['HIS:opls_507', 'HIS:opls_511', '686'], dtype='<U21'),
#  array(['CYS:opls_206', 'CYS:opls_200', '614'], dtype='<U21'),
#  array(['PRO:opls_136', 'PRO:opls_136', '584'], dtype='<U21'),
#  array(['LEU:opls_238', 'LEU:opls_241', '577'], dtype='<U21'),
#  array(['TRP:opls_503', 'TRP:opls_504', '552'], dtype='<U21'),
#  array(['GLN:opls_235', 'GLN:opls_236', '551'], dtype='<U21'),
#  array(['HIS:opls_508', 'HIS:opls_507', '491'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_272', '480'], dtype='<U21'),
#  array(['THR:opls_154', 'ASP:opls_272', '475'], dtype='<U21'),
#  array(['ARG:opls_238', 'ARG:opls_241', '454'], dtype='<U21'),
#  array(['TRP:opls_500', 'TRP:opls_514', '442'], dtype='<U21'),
#  array(['ASN:opls_235', 'ASN:opls_237', '405'], dtype='<U21'),
#  array(['TRP:opls_224B', 'TRP:opls_140', '403'], dtype='<U21'),
#  array(['THR:opls_154', 'GLU:opls_272', '402'], dtype='<U21'),
#  array(['ASP:opls_274', 'ASP:opls_140', '383'], dtype='<U21'),
#  array(['GLN:opls_238', 'GLN:opls_241', '372'], dtype='<U21'),
#  array(['GLN:opls_235', 'GLN:opls_237', '326'], dtype='<U21'),
#  array(['LYS:opls_287', 'GLU:opls_272', '282'], dtype='<U21'),
#  array(['GLN:opls_238', 'GLN:opls_236', '280'], dtype='<U21'),
#  array(['LYS:opls_287', 'THR:opls_272', '245'], dtype='<U21'),
#  array(['HIS:opls_224B', 'HIS:opls_505', '221'], dtype='<U21'),
#  array(['ASP:opls_271', 'ARG:opls_301', '220'], dtype='<U21'),
#  array(['HIS:opls_505', 'HIS:opls_508', '208'], dtype='<U21'),
#  array(['HIS:opls_503', 'HIS:opls_506', '202'], dtype='<U21'),
#  array(['ASP:opls_271', 'HIS:opls_504', '201'], dtype='<U21'),
#  array(['GLU:opls_271', 'ARG:opls_301', '194'], dtype='<U21'),
#  array(['GLU:opls_271', 'ARG:opls_304', '181'], dtype='<U21'),
#  array(['ARG:opls_303', 'THR:opls_154', '169'], dtype='<U21'),
#  array(['GLN:opls_237', 'ASN:opls_236', '166'], dtype='<U21'),
#  array(['THR:opls_154', 'THR:opls_272', '129'], dtype='<U21'),
#  array(['THR:opls_271', 'ARG:opls_301', '126'], dtype='<U21'),
#  array(['ILE:opls_238', 'ILE:opls_241', '122'], dtype='<U21'),
#  array(['GLU:opls_271', 'TYR:opls_168', '121'], dtype='<U21'),
#  array(['GLN:opls_235', 'ASN:opls_240', '98'], dtype='<U21'),
#  array(['ARG:opls_303', 'THR:opls_272', '97'], dtype='<U21'),
#  array(['GLU:opls_224B', 'GLU:opls_136', '94'], dtype='<U21'),
#  array(['TYR:opls_167', 'THR:opls_272', '73'], dtype='<U21'),
#  array(['TYR:opls_224B', 'TYR:opls_149', '66'], dtype='<U21'),
#  array(['GLN:opls_136', 'GLN:opls_235', '64'], dtype='<U21'),
#  array(['LEU:opls_238', 'LEU:opls_140', '63'], dtype='<U21'),
#  array(['TYR:opls_167', 'ASP:opls_272', '61'], dtype='<U21'),
#  array(['TRP:opls_514', 'TRP:opls_146', '56'], dtype='<U21'),
#  array(['TYR:opls_167', 'TYR:opls_167', '51'], dtype='<U21'),
#  array(['ASN:opls_237', 'LEU:opls_140', '49'], dtype='<U21'),
#  array(['LEU:opls_238', 'PRO:opls_140', '45'], dtype='<U21'),
#  array(['GLU:opls_224B', 'ARG:opls_304', '42'], dtype='<U21'),
#  array(['HIS:opls_503', 'ASP:opls_140', '39'], dtype='<U21'),
#  array(['THR:opls_154', 'TYR:opls_167', '39'], dtype='<U21'),
#  array(['ARG:opls_303', 'GLN:opls_236', '38'], dtype='<U21'),
#  array(['ASN:opls_235', 'THR:opls_155', '34'], dtype='<U21'),
#  array(['ASP:opls_274', 'HIS:opls_504', '29'], dtype='<U21'),
#  array(['ASN:opls_224B', 'ILE:opls_140', '28'], dtype='<U21'),
#  array(['GLU:opls_238', 'GLU:opls_241', '28'], dtype='<U21'),
#  array(['ARG:opls_300', 'TYR:opls_167', '27'], dtype='<U21'),
#  array(['LYS:opls_238', 'ILE:opls_140', '27'], dtype='<U21'),
#  array(['LEU:opls_137', 'ASN:opls_240', '26'], dtype='<U21'),
#  array(['GLY:opls_238', 'GLY:opls_241', '24'], dtype='<U21'),
#  array(['LYS:opls_287', 'TYR:opls_167', '24'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLN:opls_236', '22'], dtype='<U21'),
#  array(['GLN:opls_136', 'CYS:opls_204', '21'], dtype='<U21'),
#  array(['ILE:opls_137', 'ASN:opls_140', '21'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_155', '20'], dtype='<U21'),
#  array(['ASN:opls_238', 'ASN:opls_241', '20'], dtype='<U21'),
#  array(['ILE:opls_224B', 'LEU:opls_140', '20'], dtype='<U21'),
#  array(['THR:opls_271', 'LYS:opls_290', '19'], dtype='<U21'),
#  array(['GLN:opls_237', 'ASN:opls_140', '18'], dtype='<U21'),
#  array(['GLU:opls_271', 'LYS:opls_290', '18'], dtype='<U21'),
#  array(['TYR:opls_145', 'GLU:opls_140', '18'], dtype='<U21'),
#  array(['GLN:opls_136', 'ASN:opls_240', '17'], dtype='<U21'),
#  array(['GLN:opls_237', 'VAL:opls_140', '17'], dtype='<U21'),
#  array(['ARG:opls_300', 'TRP:opls_504', '16'], dtype='<U21'),
#  array(['LEU:opls_135', 'VAL:opls_140', '16'], dtype='<U21'),
#  array(['PRO:opls_136', 'ASN:opls_240', '16'], dtype='<U21'),
#  array(['ASN:opls_237', 'GLN:opls_140', '15'], dtype='<U21'),
#  array(['THR:opls_224B', 'TYR:opls_146', '15'], dtype='<U21'),
#  array(['LEU:opls_136', 'ILE:opls_140', '14'], dtype='<U21'),
#  array(['LYS:opls_287', 'THR:opls_154', '14'], dtype='<U21'),
#  array(['ASN:opls_237', 'THR:opls_154', '13'], dtype='<U21'),
#  array(['THR:opls_154', 'ILE:opls_140', '13'], dtype='<U21'),
#  array(['THR:opls_238', 'ILE:opls_140', '13'], dtype='<U21'),
#  array(['TRP:opls_503', 'ARG:opls_301', '13'], dtype='<U21'),
#  array(['TYR:opls_145', 'THR:opls_140', '13'], dtype='<U21'),
#  array(['VAL:opls_224B', 'LEU:opls_140', '13'], dtype='<U21'),
#  array(['ASN:opls_136', 'GLN:opls_240', '12'], dtype='<U21'),
#  array(['GLN:opls_237', 'GLN:opls_140', '12'], dtype='<U21'),
#  array(['GLU:opls_271', 'THR:opls_155', '12'], dtype='<U21'),
#  array(['LEU:opls_135', 'ILE:opls_140', '12'], dtype='<U21'),
#  array(['TYR:opls_167', 'THR:opls_154', '12'], dtype='<U21'),
#  array(['ARG:opls_224B', 'CYS:opls_204', '11'], dtype='<U21'),
#  array(['ARG:opls_300', 'LEU:opls_140', '11'], dtype='<U21'),
#  array(['TYR:opls_238', 'TYR:opls_146', '11'], dtype='<U21'),
#  array(['ASN:opls_235', 'GLN:opls_240', '10'], dtype='<U21'),
#  array(['ILE:opls_238', 'ILE:opls_140', '10'], dtype='<U21'),
#  array(['ILE:opls_238', 'VAL:opls_140', '10'], dtype='<U21'),
#  array(['THR:opls_154', 'VAL:opls_140', '10'], dtype='<U21'),
#  array(['THR:opls_271', 'ARG:opls_304', '10'], dtype='<U21'),
#  array(['VAL:opls_224B', 'ILE:opls_140', '10'], dtype='<U21'),
#  array(['ALA:opls_135', 'VAL:opls_140', '9'], dtype='<U21'),
#  array(['PRO:opls_136', 'VAL:opls_140', '9'], dtype='<U21'),
#  array(['THR:opls_135', 'ILE:opls_140', '9'], dtype='<U21'),
#  array(['THR:opls_158', 'ARG:opls_301', '9'], dtype='<U21'),
#  array(['ARG:opls_303', 'GLU:opls_140', '8'], dtype='<U21'),
#  array(['ASN:opls_237', 'PRO:opls_140', '8'], dtype='<U21'),
#  array(['CYS:opls_206', 'ASN:opls_240', '8'], dtype='<U21'),
#  array(['VAL:opls_135', 'ARG:opls_301', '8'], dtype='<U21'),
#  array(['VAL:opls_135', 'LEU:opls_140', '8'], dtype='<U21'),
#  array(['ASP:opls_271', 'THR:opls_155', '7'], dtype='<U21'),
#  array(['GLN:opls_237', 'ARG:opls_140', '7'], dtype='<U21'),
#  array(['GLU:opls_224B', 'ARG:opls_301', '7'], dtype='<U21'),
#  array(['ILE:opls_135', 'LEU:opls_140', '7'], dtype='<U21'),
#  array(['ILE:opls_135', 'THR:opls_241', '7'], dtype='<U21'),
#  array(['LEU:opls_224B', 'ARG:opls_301', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'GLN:opls_240', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'HIS:opls_504', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'PRO:opls_140', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'THR:opls_155', '7'], dtype='<U21'),
#  array(['ARG:opls_300', 'TYR:opls_168', '6'], dtype='<U21'),
#  array(['CYS:opls_238', 'CYS:opls_204', '6'], dtype='<U21'),
#  array(['ILE:opls_135', 'THR:opls_140', '6'], dtype='<U21'),
#  array(['ILE:opls_135', 'VAL:opls_140', '6'], dtype='<U21'),
#  array(['VAL:opls_135', 'ILE:opls_140', '6'], dtype='<U21'),
#  array(['VAL:opls_238', 'VAL:opls_140', '6'], dtype='<U21'),
#  array(['ASP:opls_224B', 'GLU:opls_140', '5'], dtype='<U21'),
#  array(['CYS:opls_200', 'GLN:opls_236', '5'], dtype='<U21'),
#  array(['HIS:opls_503', 'THR:opls_154', '5'], dtype='<U21'),
#  array(['HIS:opls_503', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_135', 'ASN:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_136', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_137', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_238', 'THR:opls_155', '5'], dtype='<U21'),
#  array(['LEU:opls_135', 'ASN:opls_240', '5'], dtype='<U21'),
#  array(['LYS:opls_136', 'ILE:opls_140', '5'], dtype='<U21'),
#  array(['THR:opls_135', 'LEU:opls_140', '5'], dtype='<U21'),
#  array(['THR:opls_135', 'TYR:opls_146', '5'], dtype='<U21'),
#  array(['THR:opls_154', 'HIS:opls_511', '5'], dtype='<U21'),
#  array(['THR:opls_224B', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['THR:opls_271', 'TYR:opls_168', '5'], dtype='<U21'),
#  array(['TRP:opls_145', 'GLN:opls_140', '5'], dtype='<U21'),
#  array(['VAL:opls_135', 'HIS:opls_146', '5'], dtype='<U21'),
#  array(['VAL:opls_135', 'THR:opls_140', '5'], dtype='<U21'),
#  array(['ARG:opls_224B', 'GLN:opls_240', '4'], dtype='<U21'),
#  array(['ARG:opls_300', 'TRP:opls_503', '4'], dtype='<U21'),
#  array(['ARG:opls_303', 'TYR:opls_167', '4'], dtype='<U21'),
#  array(['ARG:opls_308', 'GLN:opls_240', '4'], dtype='<U21'),
#  array(['CYS:opls_200', 'THR:opls_140', '4'], dtype='<U21'),
#  array(['GLU:opls_136', 'ASP:opls_140', '4'], dtype='<U21'),
#  array(['GLU:opls_274', 'ARG:opls_140', '4'], dtype='<U21'),
#  array(['GLU:opls_274', 'TYR:opls_146', '4'], dtype='<U21'),
#  array(['ILE:opls_135', 'THR:opls_155', '4'], dtype='<U21'),
#  array(['LEU:opls_135', 'HIS:opls_504', '4'], dtype='<U21'),
#  array(['LEU:opls_136', 'VAL:opls_140', '4'], dtype='<U21'),
#  array(['LYS:opls_238', 'THR:opls_154', '4'], dtype='<U21'),
#  array(['PRO:opls_136', 'LEU:opls_140', '4'], dtype='<U21'),
#  array(['THR:opls_135', 'ARG:opls_301', '4'], dtype='<U21'),
#  array(['THR:opls_154', 'LEU:opls_140', '4'], dtype='<U21'),
#  array(['THR:opls_224B', 'HIS:opls_140', '4'], dtype='<U21'),
#  array(['THR:opls_238', 'PRO:opls_140', '4'], dtype='<U21'),
#  array(['TYR:opls_149', 'THR:opls_140', '4'], dtype='<U21'),
#  array(['VAL:opls_135', 'ARG:opls_140', '4'], dtype='<U21'),
#  array(['ARG:opls_136', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['ARG:opls_300', 'HIS:opls_511', '3'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_140', '3'], dtype='<U21'),
#  array(['ARG:opls_303', 'ASN:opls_236', '3'], dtype='<U21'),
#  array(['ARG:opls_308', 'ARG:opls_301', '3'], dtype='<U21'),
#  array(['ASN:opls_136', 'GLN:opls_140', '3'], dtype='<U21'),
#  array(['CYS:opls_200', 'GLN:opls_140', '3'], dtype='<U21'),
#  array(['CYS:opls_200', 'PRO:opls_140', '3'], dtype='<U21'),
#  array(['CYS:opls_206', 'GLN:opls_240', '3'], dtype='<U21'),
#  array(['CYS:opls_206', 'PRO:opls_140', '3'], dtype='<U21'),
#  array(['GLN:opls_136', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['GLN:opls_235', 'CYS:opls_204', '3'], dtype='<U21'),
#  array(['GLU:opls_224B', 'ARG:opls_140', '3'], dtype='<U21'),
#  array(['GLU:opls_274', 'THR:opls_140', '3'], dtype='<U21'),
#  array(['HIS:opls_238', 'HIS:opls_504', '3'], dtype='<U21'),
#  array(['HIS:opls_503', 'THR:opls_155', '3'], dtype='<U21'),
#  array(['HIS:opls_505', 'THR:opls_140', '3'], dtype='<U21'),
#  array(['HIS:opls_506', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['HIS:opls_507', 'VAL:opls_140', '3'], dtype='<U21'),
#  array(['ILE:opls_136', 'LYS:opls_140', '3'], dtype='<U21'),
#  array(['ILE:opls_224B', 'VAL:opls_140', '3'], dtype='<U21'),
#  array(['LEU:opls_224B', 'TRP:opls_140', '3'], dtype='<U21'),
#  array(['PRO:opls_136', 'CYS:opls_140', '3'], dtype='<U21'),
#  array(['THR:opls_135', 'ARG:opls_140', '3'], dtype='<U21'),
#  array(['THR:opls_135', 'GLU:opls_140', '3'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_300', '3'], dtype='<U21'),
#  array(['THR:opls_158', 'ILE:opls_140', '3'], dtype='<U21'),
#  array(['TRP:opls_136', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['TRP:opls_145', 'ILE:opls_140', '3'], dtype='<U21'),
#  array(['TRP:opls_503', 'ARG:opls_300', '3'], dtype='<U21'),
#  array(['ARG:opls_136', 'ILE:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_136', 'PRO:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_136', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_224B', 'ARG:opls_304', '2'], dtype='<U21'),
#  array(['ARG:opls_224B', 'LYS:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_303', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_307', 'GLU:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_307', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_308', 'TYR:opls_146', '2'], dtype='<U21'),
#  array(['ARG:opls_308', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['ASN:opls_136', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['ASN:opls_237', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ASP:opls_224B', 'LEU:opls_140', '2'], dtype='<U21'),
#  array(['ASP:opls_238', 'ASP:opls_241', '2'], dtype='<U21'),
#  array(['GLN:opls_237', 'LEU:opls_140', '2'], dtype='<U21'),
#  array(['GLU:opls_274', 'THR:opls_155', '2'], dtype='<U21'),
#  array(['GLY:opls_223B', 'ASP:opls_140', '2'], dtype='<U21'),
#  array(['GLY:opls_223B', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['HIS:opls_503', 'ARG:opls_301', '2'], dtype='<U21'),
#  array(['ILE:opls_135', 'ARG:opls_140', '2'], dtype='<U21'),
#  array(['ILE:opls_135', 'TYR:opls_146', '2'], dtype='<U21'),
#  array(['ILE:opls_136', 'HIS:opls_504', '2'], dtype='<U21'),
#  array(['ILE:opls_136', 'THR:opls_155', '2'], dtype='<U21'),
#  array(['LEU:opls_135', 'GLN:opls_140', '2'], dtype='<U21'),
#  array(['LEU:opls_137', 'ARG:opls_301', '2'], dtype='<U21'),
#  array(['LEU:opls_137', 'ILE:opls_140', '2'], dtype='<U21'),
#  array(['LYS:opls_136', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['LYS:opls_292', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['PRO:opls_136', 'CYS:opls_204', '2'], dtype='<U21'),
#  array(['PRO:opls_246', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['THR:opls_135', 'CYS:opls_204', '2'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_140', '2'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_301', '2'], dtype='<U21'),
#  array(['THR:opls_154', 'ILE:opls_241', '2'], dtype='<U21'),
#  array(['THR:opls_158', 'LEU:opls_140', '2'], dtype='<U21'),
#  array(['TRP:opls_136', 'ILE:opls_140', '2'], dtype='<U21'),
#  array(['TYR:opls_145', 'LYS:opls_140', '2'], dtype='<U21'),
#  array(['TYR:opls_167', 'TYR:opls_168', '2'], dtype='<U21'),
#  array(['VAL:opls_135', 'LYS:opls_140', '2'], dtype='<U21'),
#  array(['VAL:opls_137', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['VAL:opls_224B', 'ASN:opls_240', '2'], dtype='<U21'),
#  array(['VAL:opls_224B', 'GLN:opls_240', '2'], dtype='<U21'),
#  array(['VAL:opls_224B', 'HIS:opls_146', '2'], dtype='<U21'),
#  array(['ALA:opls_135', 'TRP:opls_504', '1'], dtype='<U21'),
#  array(['ARG:opls_136', 'GLN:opls_240', '1'], dtype='<U21'),
#  array(['ARG:opls_224B', 'TYR:opls_146', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'ASP:opls_271', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLU:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLU:opls_271', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_307', 'ALA:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_307', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['ARG:opls_307', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_308', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_308', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['ASN:opls_224B', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['ASN:opls_224B', 'CYS:opls_204', '1'], dtype='<U21'),
#  array(['ASN:opls_235', 'CYS:opls_204', '1'], dtype='<U21'),
#  array(['ASN:opls_237', 'GLN:opls_240', '1'], dtype='<U21'),
#  array(['ASN:opls_237', 'THR:opls_135', '1'], dtype='<U21'),
#  array(['ASN:opls_238', 'ASN:opls_236', '1'], dtype='<U21'),
#  array(['ASP:opls_271', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['ASP:opls_274', 'GLY:opls_140', '1'], dtype='<U21'),
#  array(['ASP:opls_274', 'HIS:opls_140', '1'], dtype='<U21'),
#  array(['ASP:opls_274', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['CYS:opls_200', 'ASN:opls_236', '1'], dtype='<U21'),
#  array(['CYS:opls_206', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['CYS:opls_224B', 'CYS:opls_206', '1'], dtype='<U21'),
#  array(['CYS:opls_224B', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'GLN:opls_136', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_235', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['GLN:opls_235', 'ILE:opls_241', '1'], dtype='<U21'),
#  array(['GLN:opls_237', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_237', 'GLN:opls_241', '1'], dtype='<U21'),
#  array(['GLU:opls_136', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['GLU:opls_224B', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['GLY:opls_223B', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_224B', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['HIS:opls_238', 'HIS:opls_503', '1'], dtype='<U21'),
#  array(['HIS:opls_238', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_503', 'LEU:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_503', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_506', 'GLY:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_506', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_507', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['ILE:opls_135', 'GLN:opls_140', '1'], dtype='<U21'),
#  array(['ILE:opls_135', 'HIS:opls_504', '1'], dtype='<U21'),
#  array(['ILE:opls_135', 'LYS:opls_241', '1'], dtype='<U21'),
#  array(['ILE:opls_136', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['ILE:opls_136', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'HIS:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['LEU:opls_136', 'GLN:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_136', 'GLN:opls_240', '1'], dtype='<U21'),
#  array(['LEU:opls_137', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_137', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_224B', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_224B', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['LEU:opls_224B', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['LYS:opls_136', 'TYR:opls_146', '1'], dtype='<U21'),
#  array(['LYS:opls_224B', 'TYR:opls_146', '1'], dtype='<U21'),
#  array(['LYS:opls_238', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['LYS:opls_292', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['LYS:opls_292', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['PRO:opls_136', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['PRO:opls_136', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['PRO:opls_245', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'HIS:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_302', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'ASP:opls_271', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'GLU:opls_271', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'THR:opls_154', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'THR:opls_241', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'VAL:opls_241', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'ARG:opls_304', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'GLU:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'TYR:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_224B', 'HIS:opls_146', '1'], dtype='<U21'),
#  array(['THR:opls_224B', 'HIS:opls_504', '1'], dtype='<U21'),
#  array(['THR:opls_224B', 'LEU:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_238', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_238', 'TYR:opls_167', '1'], dtype='<U21'),
#  array(['THR:opls_238', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['THR:opls_271', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['THR:opls_283', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_283', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['TRP:opls_145', 'LEU:opls_140', '1'], dtype='<U21'),
#  array(['TRP:opls_145', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['TRP:opls_224B', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_145', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_149', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['TYR:opls_166', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['TYR:opls_167', 'GLU:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_167', 'GLU:opls_271', '1'], dtype='<U21'),
#  array(['TYR:opls_224B', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_224B', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['VAL:opls_135', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['VAL:opls_135', 'LYS:opls_290', '1'], dtype='<U21'),
#  array(['VAL:opls_137', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['VAL:opls_137', 'LYS:opls_290', '1'], dtype='<U21'),
#  array(['VAL:opls_224B', 'ASN:opls_140', '1'], dtype='<U21')]

# %%
data_destilated = [x for x in hbond_counting_sorted if int(x[-1])>1000]
set_donors_acceptors = set([(x[0].split(':')[0], x[1].split(':')[0]) for x in data_destilated])
print(set_donors_acceptors)
# Out:
# {('GLN', 'GLN'), ('ILE', 'ILE'), ('PRO', 'PRO'), ('HIS', 'HIS'), ('ARG', 'ARG'), ('VAL', 'VAL'), ('TYR', 'GLU'), ('ARG', 'GLU'), ('GLU', 'GLU'), ('CYS', 'CYS'), ('LYS', 'LYS'), ('HIS', 'ASP'), ('LEU', 'LEU'), ('ALA', 'ALA'), ('ASN', 'ASN'), ('ARG', 'ASP'), ('ASP', 'ASP'), ('TRP', 'TRP'), ('GLY', 'GLY'), ('TYR', 'TYR'), ('THR', 'THR')}

# %%
y = set([x[0] for x in set_donors_acceptors] + [x[1] for x in set_donors_acceptors])

# %%
print(' '.join(y))
# Out:
# GLN ASP LEU THR ARG ASN HIS TYR TRP PRO ILE GLY GLU LYS CYS VAL ALA

# %% [markdown]
# New analysis with fewer residues

# %%
hbonds = HydrogenBondAnalysis(universe=u)

protein_hydrogens_sel = hbonds.guess_hydrogens("protein")
protein_acceptors_sel = hbonds.guess_acceptors("protein")

# %%
hbonds.hydrogens_sel = f"not backbone and resname GLN ASP LEU THR ARG ASN HIS TYR TRP PRO ILE GLY GLU LYS CYS VAL ALA"
hbonds.acceptors_sel = f"not backbone and resname GLN ASP LEU THR ARG ASN HIS TYR TRP PRO ILE GLY GLU LYS CYS VAL ALA"
hbonds.run()

# %%
hbond_counting_raw = hbonds.count_by_type()
hbond_counting_sorted = sorted(hbond_counting_raw, key=lambda x: int(x[-1]), reverse=True)
hbond_counting_sorted
# Out:
# [array(['VAL:opls_135', 'VAL:opls_140', '22218'], dtype='<U21'),
#  array(['ILE:opls_135', 'ILE:opls_140', '19202'], dtype='<U21'),
#  array(['LEU:opls_135', 'LEU:opls_140', '17892'], dtype='<U21'),
#  array(['THR:opls_135', 'THR:opls_140', '11665'], dtype='<U21'),
#  array(['VAL:opls_137', 'VAL:opls_135', '9985'], dtype='<U21'),
#  array(['ARG:opls_300', 'ARG:opls_301', '9881'], dtype='<U21'),
#  array(['PRO:opls_136', 'PRO:opls_140', '7694'], dtype='<U21'),
#  array(['TRP:opls_145', 'TRP:opls_146', '7581'], dtype='<U21'),
#  array(['LEU:opls_137', 'LEU:opls_135', '7109'], dtype='<U21'),
#  array(['LYS:opls_136', 'LYS:opls_140', '6832'], dtype='<U21'),
#  array(['THR:opls_224B', 'THR:opls_140', '6699'], dtype='<U21'),
#  array(['VAL:opls_224B', 'VAL:opls_140', '6582'], dtype='<U21'),
#  array(['ARG:opls_308', 'ARG:opls_140', '6180'], dtype='<U21'),
#  array(['LEU:opls_136', 'LEU:opls_140', '5682'], dtype='<U21'),
#  array(['LEU:opls_224B', 'LEU:opls_140', '5563'], dtype='<U21'),
#  array(['THR:opls_158', 'THR:opls_140', '5164'], dtype='<U21'),
#  array(['GLN:opls_136', 'GLN:opls_140', '4816'], dtype='<U21'),
#  array(['TYR:opls_145', 'TYR:opls_146', '4752'], dtype='<U21'),
#  array(['ILE:opls_136', 'ILE:opls_140', '4736'], dtype='<U21'),
#  array(['TRP:opls_145', 'TRP:opls_145', '4642'], dtype='<U21'),
#  array(['VAL:opls_137', 'VAL:opls_140', '4637'], dtype='<U21'),
#  array(['ILE:opls_137', 'ILE:opls_135', '4596'], dtype='<U21'),
#  array(['TYR:opls_145', 'TYR:opls_145', '4567'], dtype='<U21'),
#  array(['ILE:opls_224B', 'ILE:opls_137', '4309'], dtype='<U21'),
#  array(['ILE:opls_224B', 'ILE:opls_140', '4277'], dtype='<U21'),
#  array(['ARG:opls_136', 'ARG:opls_140', '4144'], dtype='<U21'),
#  array(['ARG:opls_307', 'ARG:opls_140', '4064'], dtype='<U21'),
#  array(['ILE:opls_136', 'ILE:opls_135', '3938'], dtype='<U21'),
#  array(['ARG:opls_224B', 'ARG:opls_140', '3837'], dtype='<U21'),
#  array(['ARG:opls_303', 'ARG:opls_304', '3750'], dtype='<U21'),
#  array(['LYS:opls_287', 'LYS:opls_290', '3433'], dtype='<U21'),
#  array(['ARG:opls_300', 'ASP:opls_272', '3259'], dtype='<U21'),
#  array(['THR:opls_158', 'THR:opls_154', '3172'], dtype='<U21'),
#  array(['LEU:opls_224B', 'LEU:opls_136', '3109'], dtype='<U21'),
#  array(['THR:opls_158', 'THR:opls_135', '3076'], dtype='<U21'),
#  array(['HIS:opls_503', 'ASP:opls_272', '3011'], dtype='<U21'),
#  array(['ALA:opls_135', 'ALA:opls_140', '3003'], dtype='<U21'),
#  array(['LEU:opls_136', 'LEU:opls_137', '2872'], dtype='<U21'),
#  array(['ASP:opls_271', 'ASP:opls_272', '2827'], dtype='<U21'),
#  array(['ARG:opls_302', 'ARG:opls_300', '2826'], dtype='<U21'),
#  array(['TRP:opls_136', 'TRP:opls_140', '2811'], dtype='<U21'),
#  array(['ASN:opls_237', 'ASN:opls_240', '2598'], dtype='<U21'),
#  array(['ASN:opls_136', 'ASN:opls_235', '2591'], dtype='<U21'),
#  array(['TRP:opls_501', 'TRP:opls_145', '2570'], dtype='<U21'),
#  array(['CYS:opls_206', 'CYS:opls_140', '2565'], dtype='<U21'),
#  array(['PRO:opls_245', 'PRO:opls_140', '2550'], dtype='<U21'),
#  array(['THR:opls_271', 'THR:opls_272', '2506'], dtype='<U21'),
#  array(['PRO:opls_246', 'PRO:opls_136', '2455'], dtype='<U21'),
#  array(['TYR:opls_167', 'GLU:opls_272', '2347'], dtype='<U21'),
#  array(['TYR:opls_149', 'TYR:opls_140', '2331'], dtype='<U21'),
#  array(['LYS:opls_292', 'LYS:opls_140', '2200'], dtype='<U21'),
#  array(['ALA:opls_293B', 'ALA:opls_135', '2192'], dtype='<U21'),
#  array(['CYS:opls_224B', 'CYS:opls_140', '2149'], dtype='<U21'),
#  array(['HIS:opls_505', 'HIS:opls_140', '2088'], dtype='<U21'),
#  array(['ASP:opls_224B', 'ASP:opls_140', '2079'], dtype='<U21'),
#  array(['TRP:opls_502', 'TRP:opls_145', '2051'], dtype='<U21'),
#  array(['LYS:opls_136', 'LYS:opls_136', '2048'], dtype='<U21'),
#  array(['PRO:opls_246', 'PRO:opls_140', '1995'], dtype='<U21'),
#  array(['GLU:opls_274', 'GLU:opls_140', '1934'], dtype='<U21'),
#  array(['ALA:opls_287', 'ALA:opls_290', '1924'], dtype='<U21'),
#  array(['TRP:opls_500', 'TRP:opls_501', '1896'], dtype='<U21'),
#  array(['GLY:opls_223B', 'GLY:opls_140', '1862'], dtype='<U21'),
#  array(['TYR:opls_224B', 'TYR:opls_140', '1825'], dtype='<U21'),
#  array(['LEU:opls_137', 'LEU:opls_140', '1795'], dtype='<U21'),
#  array(['THR:opls_283', 'THR:opls_140', '1749'], dtype='<U21'),
#  array(['VAL:opls_224B', 'VAL:opls_137', '1695'], dtype='<U21'),
#  array(['HIS:opls_224B', 'HIS:opls_140', '1629'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLU:opls_272', '1619'], dtype='<U21'),
#  array(['THR:opls_238', 'THR:opls_241', '1606'], dtype='<U21'),
#  array(['TRP:opls_514', 'TRP:opls_503', '1570'], dtype='<U21'),
#  array(['GLU:opls_271', 'GLU:opls_272', '1490'], dtype='<U21'),
#  array(['TYR:opls_145', 'TYR:opls_166', '1482'], dtype='<U21'),
#  array(['HIS:opls_507', 'HIS:opls_146', '1466'], dtype='<U21'),
#  array(['ARG:opls_308', 'ARG:opls_307', '1452'], dtype='<U21'),
#  array(['GLU:opls_136', 'GLU:opls_274', '1439'], dtype='<U21'),
#  array(['THR:opls_224B', 'THR:opls_158', '1365'], dtype='<U21'),
#  array(['ASP:opls_274', 'ASP:opls_271', '1323'], dtype='<U21'),
#  array(['ASN:opls_224B', 'ASN:opls_136', '1300'], dtype='<U21'),
#  array(['CYS:opls_200', 'CYS:opls_204', '1297'], dtype='<U21'),
#  array(['ARG:opls_224B', 'ARG:opls_136', '1290'], dtype='<U21'),
#  array(['ASN:opls_136', 'ASN:opls_140', '1286'], dtype='<U21'),
#  array(['TYR:opls_166', 'TYR:opls_167', '1280'], dtype='<U21'),
#  array(['TYR:opls_149', 'TYR:opls_145', '1275'], dtype='<U21'),
#  array(['ARG:opls_307', 'ARG:opls_303', '1270'], dtype='<U21'),
#  array(['ILE:opls_137', 'ILE:opls_140', '1254'], dtype='<U21'),
#  array(['GLU:opls_224B', 'GLU:opls_140', '1227'], dtype='<U21'),
#  array(['TRP:opls_224B', 'TRP:opls_136', '1218'], dtype='<U21'),
#  array(['ILE:opls_137', 'ILE:opls_136', '1183'], dtype='<U21'),
#  array(['HIS:opls_503', 'HIS:opls_504', '1180'], dtype='<U21'),
#  array(['TRP:opls_136', 'TRP:opls_500', '1173'], dtype='<U21'),
#  array(['LYS:opls_224B', 'LYS:opls_140', '1134'], dtype='<U21'),
#  array(['VAL:opls_238', 'VAL:opls_241', '1119'], dtype='<U21'),
#  array(['LYS:opls_292', 'LYS:opls_287', '1100'], dtype='<U21'),
#  array(['GLU:opls_136', 'GLU:opls_140', '1091'], dtype='<U21'),
#  array(['PRO:opls_239', 'PRO:opls_245', '1088'], dtype='<U21'),
#  array(['GLU:opls_274', 'GLU:opls_271', '1070'], dtype='<U21'),
#  array(['LYS:opls_224B', 'LYS:opls_136', '1043'], dtype='<U21'),
#  array(['LYS:opls_136', 'LYS:opls_292', '999'], dtype='<U21'),
#  array(['HIS:opls_508', 'HIS:opls_503', '996'], dtype='<U21'),
#  array(['ASN:opls_224B', 'ASN:opls_140', '987'], dtype='<U21'),
#  array(['ARG:opls_303', 'GLU:opls_272', '951'], dtype='<U21'),
#  array(['THR:opls_154', 'ASN:opls_236', '933'], dtype='<U21'),
#  array(['HIS:opls_506', 'HIS:opls_146', '910'], dtype='<U21'),
#  array(['TRP:opls_501', 'TRP:opls_502', '905'], dtype='<U21'),
#  array(['GLN:opls_224B', 'GLN:opls_140', '904'], dtype='<U21'),
#  array(['ARG:opls_303', 'ARG:opls_302', '879'], dtype='<U21'),
#  array(['GLN:opls_237', 'GLN:opls_240', '847'], dtype='<U21'),
#  array(['ARG:opls_136', 'ARG:opls_308', '826'], dtype='<U21'),
#  array(['ASN:opls_235', 'ASN:opls_236', '797'], dtype='<U21'),
#  array(['TYR:opls_238', 'TYR:opls_241', '794'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_154', '782'], dtype='<U21'),
#  array(['TRP:opls_238', 'TRP:opls_241', '779'], dtype='<U21'),
#  array(['LYS:opls_238', 'LYS:opls_241', '766'], dtype='<U21'),
#  array(['ALA:opls_293B', 'ALA:opls_140', '749'], dtype='<U21'),
#  array(['THR:opls_283', 'THR:opls_158', '737'], dtype='<U21'),
#  array(['ASN:opls_237', 'GLN:opls_236', '692'], dtype='<U21'),
#  array(['HIS:opls_507', 'HIS:opls_511', '686'], dtype='<U21'),
#  array(['CYS:opls_206', 'CYS:opls_200', '614'], dtype='<U21'),
#  array(['PRO:opls_136', 'PRO:opls_136', '584'], dtype='<U21'),
#  array(['LEU:opls_238', 'LEU:opls_241', '577'], dtype='<U21'),
#  array(['TRP:opls_503', 'TRP:opls_504', '552'], dtype='<U21'),
#  array(['GLN:opls_235', 'GLN:opls_236', '551'], dtype='<U21'),
#  array(['HIS:opls_508', 'HIS:opls_507', '491'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_272', '480'], dtype='<U21'),
#  array(['THR:opls_154', 'ASP:opls_272', '475'], dtype='<U21'),
#  array(['ARG:opls_238', 'ARG:opls_241', '454'], dtype='<U21'),
#  array(['TRP:opls_500', 'TRP:opls_514', '442'], dtype='<U21'),
#  array(['ASN:opls_235', 'ASN:opls_237', '405'], dtype='<U21'),
#  array(['TRP:opls_224B', 'TRP:opls_140', '403'], dtype='<U21'),
#  array(['THR:opls_154', 'GLU:opls_272', '402'], dtype='<U21'),
#  array(['ASP:opls_274', 'ASP:opls_140', '383'], dtype='<U21'),
#  array(['GLN:opls_238', 'GLN:opls_241', '372'], dtype='<U21'),
#  array(['GLN:opls_235', 'GLN:opls_237', '326'], dtype='<U21'),
#  array(['LYS:opls_287', 'GLU:opls_272', '282'], dtype='<U21'),
#  array(['GLN:opls_238', 'GLN:opls_236', '280'], dtype='<U21'),
#  array(['LYS:opls_287', 'THR:opls_272', '245'], dtype='<U21'),
#  array(['HIS:opls_224B', 'HIS:opls_505', '221'], dtype='<U21'),
#  array(['ASP:opls_271', 'ARG:opls_301', '220'], dtype='<U21'),
#  array(['HIS:opls_505', 'HIS:opls_508', '208'], dtype='<U21'),
#  array(['HIS:opls_503', 'HIS:opls_506', '202'], dtype='<U21'),
#  array(['ASP:opls_271', 'HIS:opls_504', '201'], dtype='<U21'),
#  array(['GLU:opls_271', 'ARG:opls_301', '194'], dtype='<U21'),
#  array(['GLU:opls_271', 'ARG:opls_304', '181'], dtype='<U21'),
#  array(['ARG:opls_303', 'THR:opls_154', '169'], dtype='<U21'),
#  array(['GLN:opls_237', 'ASN:opls_236', '166'], dtype='<U21'),
#  array(['THR:opls_154', 'THR:opls_272', '129'], dtype='<U21'),
#  array(['THR:opls_271', 'ARG:opls_301', '126'], dtype='<U21'),
#  array(['ILE:opls_238', 'ILE:opls_241', '122'], dtype='<U21'),
#  array(['GLU:opls_271', 'TYR:opls_168', '121'], dtype='<U21'),
#  array(['GLN:opls_235', 'ASN:opls_240', '98'], dtype='<U21'),
#  array(['ARG:opls_303', 'THR:opls_272', '97'], dtype='<U21'),
#  array(['GLU:opls_224B', 'GLU:opls_136', '94'], dtype='<U21'),
#  array(['TYR:opls_167', 'THR:opls_272', '73'], dtype='<U21'),
#  array(['TYR:opls_224B', 'TYR:opls_149', '66'], dtype='<U21'),
#  array(['GLN:opls_136', 'GLN:opls_235', '64'], dtype='<U21'),
#  array(['LEU:opls_238', 'LEU:opls_140', '63'], dtype='<U21'),
#  array(['TYR:opls_167', 'ASP:opls_272', '61'], dtype='<U21'),
#  array(['TRP:opls_514', 'TRP:opls_146', '56'], dtype='<U21'),
#  array(['TYR:opls_167', 'TYR:opls_167', '51'], dtype='<U21'),
#  array(['ASN:opls_237', 'LEU:opls_140', '49'], dtype='<U21'),
#  array(['LEU:opls_238', 'PRO:opls_140', '45'], dtype='<U21'),
#  array(['GLU:opls_224B', 'ARG:opls_304', '42'], dtype='<U21'),
#  array(['HIS:opls_503', 'ASP:opls_140', '39'], dtype='<U21'),
#  array(['THR:opls_154', 'TYR:opls_167', '39'], dtype='<U21'),
#  array(['ARG:opls_303', 'GLN:opls_236', '38'], dtype='<U21'),
#  array(['ASN:opls_235', 'THR:opls_155', '34'], dtype='<U21'),
#  array(['ASP:opls_274', 'HIS:opls_504', '29'], dtype='<U21'),
#  array(['ASN:opls_224B', 'ILE:opls_140', '28'], dtype='<U21'),
#  array(['GLU:opls_238', 'GLU:opls_241', '28'], dtype='<U21'),
#  array(['ARG:opls_300', 'TYR:opls_167', '27'], dtype='<U21'),
#  array(['LYS:opls_238', 'ILE:opls_140', '27'], dtype='<U21'),
#  array(['LEU:opls_137', 'ASN:opls_240', '26'], dtype='<U21'),
#  array(['GLY:opls_238', 'GLY:opls_241', '24'], dtype='<U21'),
#  array(['LYS:opls_287', 'TYR:opls_167', '24'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLN:opls_236', '22'], dtype='<U21'),
#  array(['GLN:opls_136', 'CYS:opls_204', '21'], dtype='<U21'),
#  array(['ILE:opls_137', 'ASN:opls_140', '21'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_155', '20'], dtype='<U21'),
#  array(['ASN:opls_238', 'ASN:opls_241', '20'], dtype='<U21'),
#  array(['ILE:opls_224B', 'LEU:opls_140', '20'], dtype='<U21'),
#  array(['THR:opls_271', 'LYS:opls_290', '19'], dtype='<U21'),
#  array(['GLN:opls_237', 'ASN:opls_140', '18'], dtype='<U21'),
#  array(['GLU:opls_271', 'LYS:opls_290', '18'], dtype='<U21'),
#  array(['TYR:opls_145', 'GLU:opls_140', '18'], dtype='<U21'),
#  array(['GLN:opls_136', 'ASN:opls_240', '17'], dtype='<U21'),
#  array(['GLN:opls_237', 'VAL:opls_140', '17'], dtype='<U21'),
#  array(['ARG:opls_300', 'TRP:opls_504', '16'], dtype='<U21'),
#  array(['LEU:opls_135', 'VAL:opls_140', '16'], dtype='<U21'),
#  array(['PRO:opls_136', 'ASN:opls_240', '16'], dtype='<U21'),
#  array(['ASN:opls_237', 'GLN:opls_140', '15'], dtype='<U21'),
#  array(['THR:opls_224B', 'TYR:opls_146', '15'], dtype='<U21'),
#  array(['LEU:opls_136', 'ILE:opls_140', '14'], dtype='<U21'),
#  array(['LYS:opls_287', 'THR:opls_154', '14'], dtype='<U21'),
#  array(['ASN:opls_237', 'THR:opls_154', '13'], dtype='<U21'),
#  array(['THR:opls_154', 'ILE:opls_140', '13'], dtype='<U21'),
#  array(['THR:opls_238', 'ILE:opls_140', '13'], dtype='<U21'),
#  array(['TRP:opls_503', 'ARG:opls_301', '13'], dtype='<U21'),
#  array(['TYR:opls_145', 'THR:opls_140', '13'], dtype='<U21'),
#  array(['VAL:opls_224B', 'LEU:opls_140', '13'], dtype='<U21'),
#  array(['ASN:opls_136', 'GLN:opls_240', '12'], dtype='<U21'),
#  array(['GLN:opls_237', 'GLN:opls_140', '12'], dtype='<U21'),
#  array(['GLU:opls_271', 'THR:opls_155', '12'], dtype='<U21'),
#  array(['LEU:opls_135', 'ILE:opls_140', '12'], dtype='<U21'),
#  array(['TYR:opls_167', 'THR:opls_154', '12'], dtype='<U21'),
#  array(['ARG:opls_224B', 'CYS:opls_204', '11'], dtype='<U21'),
#  array(['ARG:opls_300', 'LEU:opls_140', '11'], dtype='<U21'),
#  array(['TYR:opls_238', 'TYR:opls_146', '11'], dtype='<U21'),
#  array(['ASN:opls_235', 'GLN:opls_240', '10'], dtype='<U21'),
#  array(['ILE:opls_238', 'ILE:opls_140', '10'], dtype='<U21'),
#  array(['ILE:opls_238', 'VAL:opls_140', '10'], dtype='<U21'),
#  array(['THR:opls_154', 'VAL:opls_140', '10'], dtype='<U21'),
#  array(['THR:opls_271', 'ARG:opls_304', '10'], dtype='<U21'),
#  array(['VAL:opls_224B', 'ILE:opls_140', '10'], dtype='<U21'),
#  array(['ALA:opls_135', 'VAL:opls_140', '9'], dtype='<U21'),
#  array(['PRO:opls_136', 'VAL:opls_140', '9'], dtype='<U21'),
#  array(['THR:opls_135', 'ILE:opls_140', '9'], dtype='<U21'),
#  array(['THR:opls_158', 'ARG:opls_301', '9'], dtype='<U21'),
#  array(['ARG:opls_303', 'GLU:opls_140', '8'], dtype='<U21'),
#  array(['ASN:opls_237', 'PRO:opls_140', '8'], dtype='<U21'),
#  array(['CYS:opls_206', 'ASN:opls_240', '8'], dtype='<U21'),
#  array(['VAL:opls_135', 'ARG:opls_301', '8'], dtype='<U21'),
#  array(['VAL:opls_135', 'LEU:opls_140', '8'], dtype='<U21'),
#  array(['ASP:opls_271', 'THR:opls_155', '7'], dtype='<U21'),
#  array(['GLN:opls_237', 'ARG:opls_140', '7'], dtype='<U21'),
#  array(['GLU:opls_224B', 'ARG:opls_301', '7'], dtype='<U21'),
#  array(['ILE:opls_135', 'LEU:opls_140', '7'], dtype='<U21'),
#  array(['ILE:opls_135', 'THR:opls_241', '7'], dtype='<U21'),
#  array(['LEU:opls_224B', 'ARG:opls_301', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'GLN:opls_240', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'HIS:opls_504', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'PRO:opls_140', '7'], dtype='<U21'),
#  array(['VAL:opls_135', 'THR:opls_155', '7'], dtype='<U21'),
#  array(['ARG:opls_300', 'TYR:opls_168', '6'], dtype='<U21'),
#  array(['CYS:opls_238', 'CYS:opls_204', '6'], dtype='<U21'),
#  array(['ILE:opls_135', 'THR:opls_140', '6'], dtype='<U21'),
#  array(['ILE:opls_135', 'VAL:opls_140', '6'], dtype='<U21'),
#  array(['VAL:opls_135', 'ILE:opls_140', '6'], dtype='<U21'),
#  array(['VAL:opls_238', 'VAL:opls_140', '6'], dtype='<U21'),
#  array(['ASP:opls_224B', 'GLU:opls_140', '5'], dtype='<U21'),
#  array(['CYS:opls_200', 'GLN:opls_236', '5'], dtype='<U21'),
#  array(['HIS:opls_503', 'THR:opls_154', '5'], dtype='<U21'),
#  array(['HIS:opls_503', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_135', 'ASN:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_136', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_137', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['ILE:opls_238', 'THR:opls_155', '5'], dtype='<U21'),
#  array(['LEU:opls_135', 'ASN:opls_240', '5'], dtype='<U21'),
#  array(['LYS:opls_136', 'ILE:opls_140', '5'], dtype='<U21'),
#  array(['THR:opls_135', 'LEU:opls_140', '5'], dtype='<U21'),
#  array(['THR:opls_135', 'TYR:opls_146', '5'], dtype='<U21'),
#  array(['THR:opls_154', 'HIS:opls_511', '5'], dtype='<U21'),
#  array(['THR:opls_224B', 'VAL:opls_140', '5'], dtype='<U21'),
#  array(['THR:opls_271', 'TYR:opls_168', '5'], dtype='<U21'),
#  array(['TRP:opls_145', 'GLN:opls_140', '5'], dtype='<U21'),
#  array(['VAL:opls_135', 'HIS:opls_146', '5'], dtype='<U21'),
#  array(['VAL:opls_135', 'THR:opls_140', '5'], dtype='<U21'),
#  array(['ARG:opls_224B', 'GLN:opls_240', '4'], dtype='<U21'),
#  array(['ARG:opls_300', 'TRP:opls_503', '4'], dtype='<U21'),
#  array(['ARG:opls_303', 'TYR:opls_167', '4'], dtype='<U21'),
#  array(['ARG:opls_308', 'GLN:opls_240', '4'], dtype='<U21'),
#  array(['CYS:opls_200', 'THR:opls_140', '4'], dtype='<U21'),
#  array(['GLU:opls_136', 'ASP:opls_140', '4'], dtype='<U21'),
#  array(['GLU:opls_274', 'ARG:opls_140', '4'], dtype='<U21'),
#  array(['GLU:opls_274', 'TYR:opls_146', '4'], dtype='<U21'),
#  array(['ILE:opls_135', 'THR:opls_155', '4'], dtype='<U21'),
#  array(['LEU:opls_135', 'HIS:opls_504', '4'], dtype='<U21'),
#  array(['LEU:opls_136', 'VAL:opls_140', '4'], dtype='<U21'),
#  array(['LYS:opls_238', 'THR:opls_154', '4'], dtype='<U21'),
#  array(['PRO:opls_136', 'LEU:opls_140', '4'], dtype='<U21'),
#  array(['THR:opls_135', 'ARG:opls_301', '4'], dtype='<U21'),
#  array(['THR:opls_154', 'LEU:opls_140', '4'], dtype='<U21'),
#  array(['THR:opls_224B', 'HIS:opls_140', '4'], dtype='<U21'),
#  array(['THR:opls_238', 'PRO:opls_140', '4'], dtype='<U21'),
#  array(['TYR:opls_149', 'THR:opls_140', '4'], dtype='<U21'),
#  array(['VAL:opls_135', 'ARG:opls_140', '4'], dtype='<U21'),
#  array(['ARG:opls_136', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['ARG:opls_300', 'HIS:opls_511', '3'], dtype='<U21'),
#  array(['ARG:opls_300', 'THR:opls_140', '3'], dtype='<U21'),
#  array(['ARG:opls_303', 'ASN:opls_236', '3'], dtype='<U21'),
#  array(['ARG:opls_308', 'ARG:opls_301', '3'], dtype='<U21'),
#  array(['ASN:opls_136', 'GLN:opls_140', '3'], dtype='<U21'),
#  array(['CYS:opls_200', 'GLN:opls_140', '3'], dtype='<U21'),
#  array(['CYS:opls_200', 'PRO:opls_140', '3'], dtype='<U21'),
#  array(['CYS:opls_206', 'GLN:opls_240', '3'], dtype='<U21'),
#  array(['CYS:opls_206', 'PRO:opls_140', '3'], dtype='<U21'),
#  array(['GLN:opls_136', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['GLN:opls_235', 'CYS:opls_204', '3'], dtype='<U21'),
#  array(['GLU:opls_224B', 'ARG:opls_140', '3'], dtype='<U21'),
#  array(['GLU:opls_274', 'THR:opls_140', '3'], dtype='<U21'),
#  array(['HIS:opls_238', 'HIS:opls_504', '3'], dtype='<U21'),
#  array(['HIS:opls_503', 'THR:opls_155', '3'], dtype='<U21'),
#  array(['HIS:opls_505', 'THR:opls_140', '3'], dtype='<U21'),
#  array(['HIS:opls_506', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['HIS:opls_507', 'VAL:opls_140', '3'], dtype='<U21'),
#  array(['ILE:opls_136', 'LYS:opls_140', '3'], dtype='<U21'),
#  array(['ILE:opls_224B', 'VAL:opls_140', '3'], dtype='<U21'),
#  array(['LEU:opls_224B', 'TRP:opls_140', '3'], dtype='<U21'),
#  array(['PRO:opls_136', 'CYS:opls_140', '3'], dtype='<U21'),
#  array(['THR:opls_135', 'ARG:opls_140', '3'], dtype='<U21'),
#  array(['THR:opls_135', 'GLU:opls_140', '3'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_300', '3'], dtype='<U21'),
#  array(['THR:opls_158', 'ILE:opls_140', '3'], dtype='<U21'),
#  array(['TRP:opls_136', 'LEU:opls_140', '3'], dtype='<U21'),
#  array(['TRP:opls_145', 'ILE:opls_140', '3'], dtype='<U21'),
#  array(['TRP:opls_503', 'ARG:opls_300', '3'], dtype='<U21'),
#  array(['ARG:opls_136', 'ILE:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_136', 'PRO:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_136', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_224B', 'ARG:opls_304', '2'], dtype='<U21'),
#  array(['ARG:opls_224B', 'LYS:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_303', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_307', 'GLU:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_307', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ARG:opls_308', 'TYR:opls_146', '2'], dtype='<U21'),
#  array(['ARG:opls_308', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['ASN:opls_136', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['ASN:opls_237', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['ASP:opls_224B', 'LEU:opls_140', '2'], dtype='<U21'),
#  array(['ASP:opls_238', 'ASP:opls_241', '2'], dtype='<U21'),
#  array(['GLN:opls_237', 'LEU:opls_140', '2'], dtype='<U21'),
#  array(['GLU:opls_274', 'THR:opls_155', '2'], dtype='<U21'),
#  array(['GLY:opls_223B', 'ASP:opls_140', '2'], dtype='<U21'),
#  array(['GLY:opls_223B', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['HIS:opls_503', 'ARG:opls_301', '2'], dtype='<U21'),
#  array(['ILE:opls_135', 'ARG:opls_140', '2'], dtype='<U21'),
#  array(['ILE:opls_135', 'TYR:opls_146', '2'], dtype='<U21'),
#  array(['ILE:opls_136', 'HIS:opls_504', '2'], dtype='<U21'),
#  array(['ILE:opls_136', 'THR:opls_155', '2'], dtype='<U21'),
#  array(['LEU:opls_135', 'GLN:opls_140', '2'], dtype='<U21'),
#  array(['LEU:opls_137', 'ARG:opls_301', '2'], dtype='<U21'),
#  array(['LEU:opls_137', 'ILE:opls_140', '2'], dtype='<U21'),
#  array(['LYS:opls_136', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['LYS:opls_292', 'VAL:opls_140', '2'], dtype='<U21'),
#  array(['PRO:opls_136', 'CYS:opls_204', '2'], dtype='<U21'),
#  array(['PRO:opls_246', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['THR:opls_135', 'CYS:opls_204', '2'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_140', '2'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_301', '2'], dtype='<U21'),
#  array(['THR:opls_154', 'ILE:opls_241', '2'], dtype='<U21'),
#  array(['THR:opls_158', 'LEU:opls_140', '2'], dtype='<U21'),
#  array(['TRP:opls_136', 'ILE:opls_140', '2'], dtype='<U21'),
#  array(['TYR:opls_145', 'LYS:opls_140', '2'], dtype='<U21'),
#  array(['TYR:opls_167', 'TYR:opls_168', '2'], dtype='<U21'),
#  array(['VAL:opls_135', 'LYS:opls_140', '2'], dtype='<U21'),
#  array(['VAL:opls_137', 'THR:opls_140', '2'], dtype='<U21'),
#  array(['VAL:opls_224B', 'ASN:opls_240', '2'], dtype='<U21'),
#  array(['VAL:opls_224B', 'GLN:opls_240', '2'], dtype='<U21'),
#  array(['VAL:opls_224B', 'HIS:opls_146', '2'], dtype='<U21'),
#  array(['ALA:opls_135', 'TRP:opls_504', '1'], dtype='<U21'),
#  array(['ARG:opls_136', 'GLN:opls_240', '1'], dtype='<U21'),
#  array(['ARG:opls_224B', 'TYR:opls_146', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'ASP:opls_271', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLU:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'GLU:opls_271', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_300', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_307', 'ALA:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_307', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['ARG:opls_307', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_308', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['ARG:opls_308', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['ASN:opls_224B', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['ASN:opls_224B', 'CYS:opls_204', '1'], dtype='<U21'),
#  array(['ASN:opls_235', 'CYS:opls_204', '1'], dtype='<U21'),
#  array(['ASN:opls_237', 'GLN:opls_240', '1'], dtype='<U21'),
#  array(['ASN:opls_237', 'THR:opls_135', '1'], dtype='<U21'),
#  array(['ASN:opls_238', 'ASN:opls_236', '1'], dtype='<U21'),
#  array(['ASP:opls_271', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['ASP:opls_274', 'GLY:opls_140', '1'], dtype='<U21'),
#  array(['ASP:opls_274', 'HIS:opls_140', '1'], dtype='<U21'),
#  array(['ASP:opls_274', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['CYS:opls_200', 'ASN:opls_236', '1'], dtype='<U21'),
#  array(['CYS:opls_206', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['CYS:opls_224B', 'CYS:opls_206', '1'], dtype='<U21'),
#  array(['CYS:opls_224B', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'GLN:opls_136', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['GLN:opls_136', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_235', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['GLN:opls_235', 'ILE:opls_241', '1'], dtype='<U21'),
#  array(['GLN:opls_237', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['GLN:opls_237', 'GLN:opls_241', '1'], dtype='<U21'),
#  array(['GLU:opls_136', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['GLU:opls_224B', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['GLY:opls_223B', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_224B', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['HIS:opls_238', 'HIS:opls_503', '1'], dtype='<U21'),
#  array(['HIS:opls_238', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_503', 'LEU:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_503', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_506', 'GLY:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_506', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['HIS:opls_507', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['ILE:opls_135', 'GLN:opls_140', '1'], dtype='<U21'),
#  array(['ILE:opls_135', 'HIS:opls_504', '1'], dtype='<U21'),
#  array(['ILE:opls_135', 'LYS:opls_241', '1'], dtype='<U21'),
#  array(['ILE:opls_136', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['ILE:opls_136', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'HIS:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_135', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['LEU:opls_136', 'GLN:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_136', 'GLN:opls_240', '1'], dtype='<U21'),
#  array(['LEU:opls_137', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_137', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_224B', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['LEU:opls_224B', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['LEU:opls_224B', 'TRP:opls_146', '1'], dtype='<U21'),
#  array(['LYS:opls_136', 'TYR:opls_146', '1'], dtype='<U21'),
#  array(['LYS:opls_224B', 'TYR:opls_146', '1'], dtype='<U21'),
#  array(['LYS:opls_238', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['LYS:opls_292', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['LYS:opls_292', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['PRO:opls_136', 'ARG:opls_140', '1'], dtype='<U21'),
#  array(['PRO:opls_136', 'ARG:opls_301', '1'], dtype='<U21'),
#  array(['PRO:opls_245', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'HIS:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['THR:opls_135', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'ARG:opls_302', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'ASP:opls_271', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'GLU:opls_271', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'THR:opls_154', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'THR:opls_241', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['THR:opls_154', 'VAL:opls_241', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'ARG:opls_304', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'GLU:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'PRO:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'TYR:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_158', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_224B', 'HIS:opls_146', '1'], dtype='<U21'),
#  array(['THR:opls_224B', 'HIS:opls_504', '1'], dtype='<U21'),
#  array(['THR:opls_224B', 'LEU:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_238', 'LYS:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_238', 'TYR:opls_167', '1'], dtype='<U21'),
#  array(['THR:opls_238', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['THR:opls_271', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['THR:opls_283', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['THR:opls_283', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['TRP:opls_145', 'LEU:opls_140', '1'], dtype='<U21'),
#  array(['TRP:opls_145', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['TRP:opls_224B', 'VAL:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_145', 'ILE:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_149', 'TYR:opls_168', '1'], dtype='<U21'),
#  array(['TYR:opls_166', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['TYR:opls_167', 'GLU:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_167', 'GLU:opls_271', '1'], dtype='<U21'),
#  array(['TYR:opls_224B', 'THR:opls_140', '1'], dtype='<U21'),
#  array(['TYR:opls_224B', 'THR:opls_155', '1'], dtype='<U21'),
#  array(['VAL:opls_135', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['VAL:opls_135', 'LYS:opls_290', '1'], dtype='<U21'),
#  array(['VAL:opls_137', 'CYS:opls_140', '1'], dtype='<U21'),
#  array(['VAL:opls_137', 'LYS:opls_290', '1'], dtype='<U21'),
#  array(['VAL:opls_224B', 'ASN:opls_140', '1'], dtype='<U21')]

# %%
def process_hbond_metadata(hbond_metadata):
    processed_data = []
    for x in hbond_metadata:
        #hbond_donor_acceptor = [x.segid.split('_')[-1], str(x.resnum), x.resname, x.name]
        if x.resnum%32 == 0:
            resnum = 32
        else:
            resnum = x.resnum%32
        hbond_donor_acceptor = [x.segid.split('_')[-1],str(resnum), x.resname, x.name]
        hbond_identifier = '-'.join(hbond_donor_acceptor)
        processed_data.append(hbond_identifier)
        
    return processed_data

# %%
import pandas as pd
df = pd.DataFrame(columns = ['frame', 'donor', 'donor-H', 'acceptor'])

for i in range(len(hbonds.results.hbonds)):
    hbond = hbonds.results.hbonds[i]
    frame, donor_ix, hydrogen_ix, acceptor_ix = hbond[:4].astype(int)

    u.trajectory[frame]
    hbond_metadata = u.atoms[[donor_ix, hydrogen_ix, acceptor_ix]]
    
    y1, y2, y3 = process_hbond_metadata(hbond_metadata)
    if '-'.join(y1.split('-')[:3]) != '-'.join(y3.split('-')[:3]):
        df.loc[i] = [frame] + [y1, y2, y3]

# %%
df
# Out:
#        frame         donor        donor-H       acceptor
# 13         0   A-7-ASN-ND2   A-7-ASN-HD21  B-13-LEU-HD12
# 36         0  A-26-THR-OG1   A-26-THR-HG1   H-25-GLU-OE1
# 39         0  A-28-ARG-NH2  A-28-ARG-HH22   A-24-THR-OG1
# 104        0   C-10-ILE-CA    C-10-ILE-HA  C-14-VAL-HG23
# 126        0  C-26-THR-OG1   C-26-THR-HG1   B-25-GLU-OE1
# ...      ...           ...            ...            ...
# 374534  1000  F-21-HIS-ND1   F-21-HIS-HD1   G-22-ASP-OD2
# 374567  1000  G-21-HIS-ND1   G-21-HIS-HD1   H-22-ASP-OD1
# 374614  1000   H-20-VAL-CA    H-20-VAL-HA  H-23-LEU-HD13
# 374618  1000  H-23-LEU-CD1  H-23-LEU-HD13    H-20-VAL-HA
# 374627  1000   H-29-TYR-OH    H-29-TYR-HH   H-25-GLU-OE1
#
# [18863 rows x 4 columns]

# %%
df1 = df[['donor', 'acceptor']].drop_duplicates()

# %%
df1[['ILE' in x for x in df1['donor'].values]]
# Out:
#                donor       acceptor
# 104      C-10-ILE-CA  C-14-VAL-HG23
# 2814     C-10-ILE-CB     C-7-ASN-HA
# 4471    A-30-ILE-CG1   A-31-LYS-HG1
# 7520     E-10-ILE-CD  E-13-LEU-HD11
# 10698    B-10-ILE-CA  B-13-LEU-HD11
# ...              ...            ...
# 326667   E-10-ILE-CD     E-7-ASN-HA
# 326820  H-30-ILE-CG2     H-32-THR-H
# 335094   D-17-ILE-CA  D-20-VAL-HG21
# 335339  A-30-ILE-CG2     A-32-THR-H
# 364527  D-30-ILE-CG2  D-32-THR-HG23
#
# [87 rows x 2 columns]

# %%
len(df), len(df1)
# Out:
# (18863, 989)

# %%
len(set(['-'.join(x.split('-')[1:]) for x in df1['donor'].values]))
set(['-'.join(x.split('-')[1:]) for x in df1['donor'].values])
# Out:
# {'1-ALA-CB',
#  '10-ILE-CA',
#  '10-ILE-CB',
#  '10-ILE-CD',
#  '10-ILE-CG1',
#  '10-ILE-CG2',
#  '10-ILE-N',
#  '11-CYS-CA',
#  '11-CYS-CB',
#  '11-CYS-SG',
#  '12-GLN-CB',
#  '12-GLN-CD',
#  '12-GLN-CG',
#  '12-GLN-NE2',
#  '13-LEU-CA',
#  '13-LEU-CB',
#  '13-LEU-CD1',
#  '13-LEU-CD2',
#  '13-LEU-CG',
#  '14-VAL-CA',
#  '14-VAL-CB',
#  '14-VAL-CG1',
#  '14-VAL-CG2',
#  '15-PRO-CA',
#  '15-PRO-CB',
#  '15-PRO-CD',
#  '15-PRO-CG',
#  '16-THR-CA',
#  '16-THR-CB',
#  '16-THR-CG2',
#  '16-THR-N',
#  '16-THR-OG1',
#  '17-ILE-CA',
#  '17-ILE-CB',
#  '17-ILE-CD',
#  '17-ILE-CG1',
#  '17-ILE-CG2',
#  '17-ILE-N',
#  '18-THR-CA',
#  '18-THR-CB',
#  '18-THR-CG2',
#  '18-THR-OG1',
#  '19-GLY-CA',
#  '2-PRO-CB',
#  '2-PRO-CG',
#  '20-VAL-CA',
#  '20-VAL-CG1',
#  '20-VAL-CG2',
#  '20-VAL-N',
#  '21-HIS-CA',
#  '21-HIS-CB',
#  '21-HIS-CD2',
#  '21-HIS-CE1',
#  '21-HIS-N',
#  '21-HIS-ND1',
#  '22-ASP-CA',
#  '22-ASP-CB',
#  '22-ASP-CG',
#  '23-LEU-CA',
#  '23-LEU-CB',
#  '23-LEU-CD1',
#  '23-LEU-CD2',
#  '23-LEU-CG',
#  '24-THR-CA',
#  '24-THR-CB',
#  '24-THR-CG2',
#  '24-THR-OG1',
#  '25-GLU-CA',
#  '25-GLU-CB',
#  '25-GLU-CD',
#  '25-GLU-CG',
#  '26-THR-CA',
#  '26-THR-CB',
#  '26-THR-CG2',
#  '26-THR-OG1',
#  '27-VAL-CA',
#  '27-VAL-CB',
#  '27-VAL-CG1',
#  '27-VAL-CG2',
#  '28-ARG-CA',
#  '28-ARG-CB',
#  '28-ARG-CD',
#  '28-ARG-CG',
#  '28-ARG-NE',
#  '28-ARG-NH1',
#  '28-ARG-NH2',
#  '29-TYR-CA',
#  '29-TYR-CB',
#  '29-TYR-CD1',
#  '29-TYR-CD2',
#  '29-TYR-CE1',
#  '29-TYR-CE2',
#  '29-TYR-CZ',
#  '29-TYR-OH',
#  '3-LEU-CA',
#  '3-LEU-CB',
#  '3-LEU-CD1',
#  '3-LEU-CD2',
#  '3-LEU-CG',
#  '3-LEU-N',
#  '30-ILE-CA',
#  '30-ILE-CB',
#  '30-ILE-CD',
#  '30-ILE-CG1',
#  '30-ILE-CG2',
#  '31-LYS-CA',
#  '31-LYS-CB',
#  '31-LYS-CD',
#  '31-LYS-CE',
#  '31-LYS-CG',
#  '31-LYS-N',
#  '31-LYS-NZ',
#  '32-THR-C',
#  '32-THR-CA',
#  '32-THR-CB',
#  '32-THR-CG2',
#  '32-THR-N',
#  '32-THR-OG1',
#  '4-VAL-CA',
#  '4-VAL-CG1',
#  '4-VAL-CG2',
#  '5-ARG-CA',
#  '5-ARG-CB',
#  '5-ARG-CD',
#  '5-ARG-CG',
#  '5-ARG-NH2',
#  '6-TRP-CA',
#  '6-TRP-CB',
#  '6-TRP-CE3',
#  '6-TRP-CZ3',
#  '6-TRP-NE1',
#  '7-ASN-CA',
#  '7-ASN-CB',
#  '7-ASN-CG',
#  '7-ASN-ND2',
#  '8-ARG-CA',
#  '8-ARG-CB',
#  '8-ARG-CD',
#  '8-ARG-CG',
#  '8-ARG-NE',
#  '8-ARG-NH1',
#  '8-ARG-NH2',
#  '9-VAL-CA',
#  '9-VAL-CB',
#  '9-VAL-CG1',
#  '9-VAL-CG2'}

# %%
len(set(['-'.join(x.split('-')[1:]) for x in df1['acceptor'].values]))
set(['-'.join(x.split('-')[1:]) for x in df1['acceptor'].values])
# Out:
# {'1-ALA-HB2',
#  '10-ILE-H',
#  '10-ILE-HA',
#  '10-ILE-HB',
#  '10-ILE-HD1',
#  '10-ILE-HD2',
#  '10-ILE-HD3',
#  '10-ILE-HG12',
#  '10-ILE-HG21',
#  '10-ILE-HG22',
#  '10-ILE-HG23',
#  '11-CYS-HA',
#  '11-CYS-HB1',
#  '11-CYS-HB2',
#  '11-CYS-HG',
#  '12-GLN-HB1',
#  '12-GLN-HB2',
#  '12-GLN-HE21',
#  '12-GLN-HE22',
#  '12-GLN-HG1',
#  '12-GLN-HG2',
#  '12-GLN-OE1',
#  '13-LEU-HA',
#  '13-LEU-HB1',
#  '13-LEU-HB2',
#  '13-LEU-HD11',
#  '13-LEU-HD12',
#  '13-LEU-HD13',
#  '13-LEU-HD21',
#  '13-LEU-HD22',
#  '13-LEU-HD23',
#  '13-LEU-HG',
#  '14-VAL-HA',
#  '14-VAL-HG11',
#  '14-VAL-HG12',
#  '14-VAL-HG13',
#  '14-VAL-HG21',
#  '14-VAL-HG22',
#  '14-VAL-HG23',
#  '15-PRO-HA',
#  '15-PRO-HB1',
#  '15-PRO-HB2',
#  '15-PRO-HD1',
#  '15-PRO-HD2',
#  '15-PRO-HG1',
#  '16-THR-CG2',
#  '16-THR-HA',
#  '16-THR-HB',
#  '16-THR-HG1',
#  '16-THR-HG21',
#  '16-THR-HG22',
#  '16-THR-HG23',
#  '16-THR-OG1',
#  '17-ILE-H',
#  '17-ILE-HA',
#  '17-ILE-HB',
#  '17-ILE-HD1',
#  '17-ILE-HD2',
#  '17-ILE-HD3',
#  '17-ILE-HG11',
#  '17-ILE-HG12',
#  '17-ILE-HG21',
#  '17-ILE-HG22',
#  '17-ILE-HG23',
#  '18-THR-HA',
#  '18-THR-HB',
#  '18-THR-HG1',
#  '18-THR-HG21',
#  '18-THR-HG23',
#  '18-THR-OG1',
#  '19-GLY-HA1',
#  '19-GLY-HA2',
#  '2-PRO-HB1',
#  '2-PRO-HD1',
#  '2-PRO-HG1',
#  '20-VAL-HA',
#  '20-VAL-HG12',
#  '20-VAL-HG21',
#  '20-VAL-HG22',
#  '20-VAL-HG23',
#  '21-HIS-HA',
#  '21-HIS-HB1',
#  '21-HIS-HB2',
#  '21-HIS-HD1',
#  '21-HIS-HD2',
#  '21-HIS-HE1',
#  '21-HIS-NE2',
#  '22-ASP-CG',
#  '22-ASP-HA',
#  '22-ASP-HB1',
#  '22-ASP-HB2',
#  '22-ASP-OD1',
#  '22-ASP-OD2',
#  '23-LEU-HA',
#  '23-LEU-HB1',
#  '23-LEU-HB2',
#  '23-LEU-HD11',
#  '23-LEU-HD12',
#  '23-LEU-HD13',
#  '23-LEU-HD21',
#  '23-LEU-HD22',
#  '23-LEU-HD23',
#  '23-LEU-HG',
#  '24-THR-HA',
#  '24-THR-HB',
#  '24-THR-HG1',
#  '24-THR-HG23',
#  '24-THR-OG1',
#  '25-GLU-CD',
#  '25-GLU-HA',
#  '25-GLU-HB1',
#  '25-GLU-HG1',
#  '25-GLU-HG2',
#  '25-GLU-OE1',
#  '25-GLU-OE2',
#  '26-THR-HA',
#  '26-THR-HB',
#  '26-THR-HG1',
#  '26-THR-HG21',
#  '26-THR-HG22',
#  '26-THR-HG23',
#  '26-THR-OG1',
#  '27-VAL-H',
#  '27-VAL-HA',
#  '27-VAL-HB',
#  '27-VAL-HG11',
#  '27-VAL-HG12',
#  '27-VAL-HG13',
#  '27-VAL-HG21',
#  '27-VAL-HG22',
#  '27-VAL-HG23',
#  '28-ARG-CZ',
#  '28-ARG-HA',
#  '28-ARG-HB1',
#  '28-ARG-HB2',
#  '28-ARG-HD1',
#  '28-ARG-HD2',
#  '28-ARG-HE',
#  '28-ARG-HG1',
#  '28-ARG-HG2',
#  '28-ARG-HH11',
#  '28-ARG-HH12',
#  '28-ARG-HH21',
#  '28-ARG-HH22',
#  '28-ARG-NH1',
#  '28-ARG-NH2',
#  '29-TYR-HB2',
#  '29-TYR-HD1',
#  '29-TYR-HD2',
#  '29-TYR-HE1',
#  '29-TYR-HE2',
#  '29-TYR-HH',
#  '29-TYR-OH',
#  '3-LEU-HA',
#  '3-LEU-HB2',
#  '3-LEU-HD11',
#  '3-LEU-HD12',
#  '3-LEU-HD21',
#  '3-LEU-HD22',
#  '3-LEU-HD23',
#  '3-LEU-HG',
#  '30-ILE-HA',
#  '30-ILE-HB',
#  '30-ILE-HD1',
#  '30-ILE-HD2',
#  '30-ILE-HD3',
#  '30-ILE-HG11',
#  '30-ILE-HG12',
#  '30-ILE-HG21',
#  '30-ILE-HG22',
#  '30-ILE-HG23',
#  '31-LYS-H',
#  '31-LYS-HB2',
#  '31-LYS-HD1',
#  '31-LYS-HD2',
#  '31-LYS-HE1',
#  '31-LYS-HG1',
#  '31-LYS-HG2',
#  '31-LYS-HZ1',
#  '31-LYS-HZ2',
#  '31-LYS-HZ3',
#  '32-THR-H',
#  '32-THR-HA',
#  '32-THR-HB',
#  '32-THR-HG1',
#  '32-THR-HG22',
#  '32-THR-HG23',
#  '32-THR-O1',
#  '32-THR-O2',
#  '32-THR-OG1',
#  '4-VAL-HA',
#  '4-VAL-HB',
#  '4-VAL-HG12',
#  '4-VAL-HG13',
#  '4-VAL-HG21',
#  '4-VAL-HG22',
#  '4-VAL-HG23',
#  '5-ARG-HA',
#  '5-ARG-HB1',
#  '5-ARG-HG2',
#  '5-ARG-HH21',
#  '5-ARG-HH22',
#  '5-ARG-NH2',
#  '6-TRP-HB1',
#  '6-TRP-HD1',
#  '6-TRP-HE1',
#  '6-TRP-HE3',
#  '6-TRP-HZ3',
#  '6-TRP-NE1',
#  '7-ASN-HA',
#  '7-ASN-HB1',
#  '7-ASN-HB2',
#  '7-ASN-HD21',
#  '7-ASN-HD22',
#  '7-ASN-OD1',
#  '8-ARG-HA',
#  '8-ARG-HB2',
#  '8-ARG-HD1',
#  '8-ARG-HE',
#  '8-ARG-HG1',
#  '8-ARG-HG2',
#  '8-ARG-HH11',
#  '8-ARG-HH12',
#  '8-ARG-HH21',
#  '9-VAL-HA',
#  '9-VAL-HB',
#  '9-VAL-HG11',
#  '9-VAL-HG12',
#  '9-VAL-HG13',
#  '9-VAL-HG21',
#  '9-VAL-HG22',
#  '9-VAL-HG23'}

# %%
# Intra-chain
## Backbone - Backbone

## Backbone - SC

## SC - SC

# Inter-chain

## Backbone - Backbone

## Backbone - SC

## SC - SC

# %%
selection = u.select_atoms('protein')
selection
# Out:
# <AtomGroup with 4296 atoms>

# %%
selection = u.select_atoms('protein and segid seg_0_Protein_chain_A')
selection
# Out:
# <AtomGroup with 537 atoms>

# %%
selection = u.select_atoms('backbone and segid seg_0_Protein_chain_A')
selection
# Out:
# <AtomGroup with 127 atoms>

# %%
selection = u.select_atoms('not backbone and segid seg_0_Protein_chain_A')
selection
# Out:
# <AtomGroup with 410 atoms>

# %%
Chains = ['A', 'B','C','D','E','F','G','H']

protein_chains = {}
for i in range(len(Chains)):
    chain_segid = 'seg_'+str(i)+'_Protein_chain_' + Chains[i]
    protein_chains[Chains[i]] = u.select_atoms('segid ' + chain_segid)
