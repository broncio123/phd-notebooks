# %%
import os
import sys
import numpy
import json
import subprocess
import isambard_dev
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# Import modules to get methods for interaction analysis

# %%
new_module = "/home/ba13026/mpmodeling/analysis/"
if new_module not in sys.path:
    sys.path.append(new_module)

# %%
from insert2db_interactions import get_OH_atoms
from insert2db_interactions import get_KIHs
# from insert2db_interactions import get_COM_bb_distance
from insert2db_interactions import interaction_direction
import json

# %%
def get_assembly_radius(file, rtype):
    try:
        # Convert to AMPAL
        p = isambard_dev.ampal.convert_pdb_to_ampal(file)
        # Number of chains
        n_chains = len(p.sequences)
        # Extract Complex and Chain COM data 
        if rtype == 'bb':
            ccom = p.backbone.centre_of_mass
            chains_com = [p[k].backbone.centre_of_mass for k in range(n_chains)]
        elif rtype == 'all' :
            ccom = p.centre_of_mass
            chains_com = [p[k].centre_of_mass for k in range(n_chains)]
        com_dd_distances = []
        for k in range(n_chains):
                com_dd_distances.append(numpy.linalg.norm(chains_com[k] - ccom))
        return com_dd_distances
#         return json.dumps(com_dd_distances)
    except:
        return 'NoFile'

# %% [markdown]
# <h2 style="text-align:center">Repetion of interactions analysis for narrow/wide <em>cWza</em> models</h2>

# %% [markdown]
# 1. Find backbone-assembly radii values ($r_{BB}$) for all models,
#
# 2. Filter out those models with mean narrow and wide radii, within a common standard deviation,
# > Check identity is identical with currently analysed models
#
# 3. Find H-bonds and KIHs for these models; make sure no *spurious protons* are added,
#
# 4. See whether any noticeable difference appears between narrow and wide groups,
#
# 5. Compare with current results
#
# 6. Visualise location of H-bonds and KIHs in PDB. VMD shots.

# %% [markdown]
# **1. Find backbone-assembly radii values (rBB) for all models**

# %%
path0 = "/projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/"

# %%
r_bb_data = []
r_bbsc_data = []
for i in range(1000):
    pdb = path0+'/input/'+'refined1_0001_INPUT_'+format(i+1,'04d')+'_ignorechain'+'.pdb'
    r_bb_data.append(numpy.mean(get_assembly_radius(pdb,'bb')))
    r_bbsc_data.append(numpy.mean(get_assembly_radius(pdb,'all')))

# %% [markdown]
# Saved radial data in JSON file

# %%
with open(path0+'/'+'md_relax'+'/'+'BB-Assembly_Radii_Original.json', 'w') as fp:
    json.dump(r_bb_data, fp)

# %% [raw]
# with open(path0+'/'+'md_relax'+'/'+'BB-Assembly_Radii_Original.json', 'r') as f:
#     r_bb_data = json.load(f)

# %%
com_hist = plt.figure(dpi=80)

###################### BACKBONE ####################################
r_data = r_bb_data
plt.hist(r_data,bins=90,color='orange',label='Original:BB')

# Find meand and std of bb-assembly radius
mean_r = numpy.mean(r_data)
std = numpy.std(r_data)

plt.plot((mean_r-std,mean_r-std),(0,60),linestyle="-",linewidth=3,color="green",alpha=0.75)
plt.plot((mean_r,mean_r),(0,60),linestyle="--",linewidth=1,color="green",alpha=0.75,label="Sample:BB")
plt.plot((mean_r+std,mean_r+std),(0,60),linestyle="-",linewidth=3,color="green",alpha=0.75)
###################### BACKBONE and SIDECHAINS ####################################
r_data = r_bbsc_data
plt.hist(r_data,bins=90,color='blue',label='Original:BB+SC',alpha=0.4)

# Find meand and std of bb-assembly radius
mean_r = numpy.mean(r_data)
std = numpy.std(r_data)

plt.plot((mean_r-std,mean_r-std),(0,60),linestyle="-",linewidth=3,color="blue",alpha=0.75)
plt.plot((mean_r,mean_r),(0,60),linestyle="--",linewidth=1,color="blue",alpha=0.75,label="Sample:BB+SC")
plt.plot((mean_r+std,mean_r+std),(0,60),linestyle="-",linewidth=3,color="blue",alpha=0.75)
########################################################################
plt.title("cWzaY373C: All docked models",fontsize=20)
plt.xlabel("BB-Assembly radius [$\AA$]",fontsize=20)
plt.ylabel("Absolute frequency",fontsize=20)

plt.legend(loc='best')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print('Average and STD BB-Assembly radius: ', numpy.mean(r_bb_data), numpy.std(r_bb_data))
print('Average and STD BB+SC-Assembly radius: ', numpy.mean(r_bbsc_data), numpy.std(r_bbsc_data))
# Out:
# Average and STD BB-Assembly radius:  15.3108718754 1.25302079414
# Average and STD BB+SC-Assembly radius:  15.7505226353 1.22308457522

# %% [markdown]
# **2. Find all models corresponding to the samples of models**

# %%
# Sample for Narrow/Wide models
models = []
for i in range(1000):
    d = r_bb_data[i]
    if (mean_rbb-std) < d < (mean_rbb+std):
        models.append(format(i+1,'04d'))

# %% [markdown]
# Number of models

# %%
models = [format(i+1,'04d') for i in range(1000)]

# %%
len(models)
# Out:
# 1000

# %% [markdown]
# **Create AB chains PDB**

# %%
for i in range(1000):
    pdbname = 'refined1_0001_INPUT_'+format(i+1,'04d')+'_ignorechain'+'.pdb'
    pdb = path0+'/input/'+pdbname
    if not os.path.isdir(path0+'/md_relax/ABchains'):
        subprocess.call(['mkdir',path0+'/md_relax/ABchains'])
    else:
        output_pdb = path0+'/md_relax/ABchains/'+pdbname
        # !pymol -qc ~/mpmodeling/tools/create_ABchain_pdbs.py -- $pdb $output_pdb

# %% [markdown]
# **3. Find H-bonds and KIHs for these models**

# %% [markdown]
# **<p style="text-align:center"> H-bonds </p>**

# %%
S_hbonds = {}
for nmodel in models:
    path_chainAB = path0+'/md_relax/ABchains/'+'refined1_0001_INPUT_'+str(nmodel)+'_ignorechain.pdb'
#     !ls {path_chainAB}
    S_reduced_interactions_model = []
    for x in get_OH_atoms(path_chainAB):
        hb_raw = json.loads(x)
        hb = json.dumps(hb_raw[:-1]+[interaction_direction(hb_raw[-1])])
        S_reduced_interactions_model.append(hb)
    S_hbonds[nmodel] = list(set(S_reduced_interactions_model))

# %%
S_hbonds_sample = set()
for s in list(S_hbonds.values()):
    S_hbonds_sample = S_hbonds_sample.union(set(s))

# %%
S_hbonds_sample
# Out:
# {'["11", "HG", "12", "OE1", -1]',
#  '["11", "HG", "12", "OE1", 0]',
#  '["11", "HG", "16", "OG1", -1]',
#  '["16", "HG1", "7", "OD1", 1]',
#  '["21", "HD1", "26", "OG1", -1]',
#  '["21", "HE2", "25", "OE2", 0]',
#  '["21", "HE2", "26", "OG1", -1]',
#  '["24", "HG1", "28", "NH1", 0]',
#  '["26", "HG1", "21", "ND1", 1]',
#  '["26", "HG1", "21", "NE2", 1]',
#  '["26", "HG1", "25", "OE1", 1]',
#  '["26", "HG1", "25", "OE2", 1]',
#  '["28", "HE", "25", "OE1", 0]',
#  '["28", "HE", "26", "OG1", -1]',
#  '["28", "HE", "29", "SG", -1]',
#  '["29", "HG", "21", "NE2", 1]',
#  '["29", "HG", "25", "OE1", 1]',
#  '["29", "HG", "25", "OE2", 1]',
#  '["29", "HG", "28", "NH1", 1]',
#  '["29", "HG", "28", "NH2", 1]',
#  '["6", "HE1", "11", "OG", -1]',
#  '["6", "HE1", "12", "OE1", -1]'}

# %%
S_hbonds_ordered = []
for resn in range(1,33):
    for hb in S_hbonds_sample:
        x = json.loads(hb)
        if int(x[0]) == resn:
            S_hbonds_ordered.append(json.dumps(x))

# %%
Hbonds_stats_sample = {}
for nmodel in models:
    hbonds_model = S_hbonds[str(nmodel)]
    # Define OH-atom type decomposition vector
    shb_vector = []
    for shb in S_hbonds_ordered:
        c = 0
        for hb in hbonds_model:
            if hb == shb:
                c+=1
        shb_vector.append(c)
    Hbonds_stats_sample[nmodel] = shb_vector

# %% [markdown]
# **<p style="text-align:center"> KIHs </p>**

# %%
S_kihs = {}
for nmodel in models:
    path_chainAB = path0+'/md_relax/ABchains/refined1_0001_INPUT_'+str(nmodel)+'_ignorechain.pdb'
    #!ls {path_chainAB}
    S_kihs[nmodel] = []
    for x in get_KIHs(path_chainAB):
        kih_raw = json.loads(x)
        kih = json.dumps(kih_raw[:-1]+[interaction_direction(kih_raw[-1])])
        S_kihs[nmodel].append(kih)

# %%
S_kihs_sample = set()
for s in list(S_kihs.values()):
    S_kihs_sample = S_kihs_sample.union(set(s))

# %%
S_kihs_sample
# Out:
# {'["10", "16", "19", "20", "23", -1]',
#  '["11", "9", "12", "13", "16", -1]',
#  '["12", "1", "2", "3", "6", 1]',
#  '["12", "1", "3", "4", "7", 1]',
#  '["13", "1", "3", "4", "7", 1]',
#  '["14", "16", "19", "20", "23", -1]',
#  '["15", "3", "6", "7", "10", 1]',
#  '["16", "10", "11", "14", "15", 1]',
#  '["16", "11", "14", "15", "18", 1]',
#  '["16", "14", "11", "15", "10", 1]',
#  '["16", "14", "11", "7", "10", 1]',
#  '["16", "14", "11", "7", "15", 1]',
#  '["16", "3", "4", "7", "10", 1]',
#  '["16", "3", "6", "7", "10", 1]',
#  '["16", "3", "7", "10", "11", 1]',
#  '["16", "3", "7", "10", "14", 1]',
#  '["16", "7", "10", "11", "14", 1]',
#  '["16", "7", "10", "14", "11", 1]',
#  '["16", "7", "3", "10", "11", 1]',
#  '["16", "7", "3", "10", "6", 1]',
#  '["18", "16", "19", "20", "23", -1]',
#  '["18", "19", "20", "22", "23", -1]',
#  '["19", "14", "17", "18", "21", 1]',
#  '["2", "4", "7", "8", "11", -1]',
#  '["21", "19", "22", "23", "26", -1]',
#  '["21", "22", "25", "26", "29", -1]',
#  '["23", "14", "17", "18", "21", 1]',
#  '["23", "18", "21", "22", "25", 1]',
#  '["23", "21", "24", "25", "28", 1]',
#  '["23", "22", "25", "21", "18", 1]',
#  '["25", "23", "26", "27", "30", -1]',
#  '["26", "17", "20", "21", "24", 1]',
#  '["26", "21", "24", "25", "28", 1]',
#  '["28", "22", "25", "26", "29", -1]',
#  '["28", "23", "26", "27", "30", -1]',
#  '["29", "21", "24", "25", "28", 1]',
#  '["29", "24", "25", "27", "28", 1]',
#  '["29", "24", "25", "28", "31", 1]',
#  '["29", "24", "27", "28", "31", 1]',
#  '["3", "9", "12", "13", "16", -1]',
#  '["7", "12", "13", "15", "16", -1]',
#  '["7", "9", "12", "13", "16", -1]',
#  '["9", "1", "3", "4", "7", 1]'}

# %%
S_kihs_ordered = []
for resn in range(1,33):
    for kih in S_kihs_sample:
        x = json.loads(kih)
        if int(x[0]) == resn:
            S_kihs_ordered.append(json.dumps(x))

# %%
KIHs_stats_sample = {}
for nmodel in models:
    kihs_model = S_kihs[str(nmodel)]
    skih_vector = []
    for skih in S_kihs_ordered:
        c = 0
        for kih in kihs_model:
            if kih == skih:
                c+=1
        skih_vector.append(c)
    KIHs_stats_sample[nmodel] = skih_vector

# %% [markdown]
# All plotted data

# %%
fig_hb_sample, ax = plt.subplots(2,1,figsize=(12,12))
################################################################
S = S_hbonds_ordered

X = numpy.zeros(len(S))
N = 0
for pdb in list(Hbonds_stats_sample.keys()):
    x = Hbonds_stats_sample[pdb]
    X = X + numpy.asarray(x)
    N += 1
        
ax[0].bar(numpy.arange(len(S)),X/float(N),color="orange",width=0.25,label="Mixed: "+str(N)+" models")

ax[0].set_xlim(-0.5,len(S)+0.5)
ax[0].set_ylim(0,1.2)

ax[0].set_xticks(range(len(S)))
ax[0].set_xticklabels(["s"+str(i) for i in range(len(S))],rotation=45)
for i in range(len(S)):
    ax[0].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[0].set_ylabel("Probability",fontsize=20)
    
for i in range(len(S)):
    ax[0].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

ax[0].set_title("H-bonds HO-atoms : cWzaY373C docked models",fontsize=25)
ax[0].legend(loc='best')
################################################################
S = S_kihs_ordered

X = numpy.zeros(len(S))
N = 0
for pdb in list(KIHs_stats_sample.keys()):
    x = KIHs_stats_sample[pdb]
    X = X + numpy.asarray(x)
    N += 1

ax[1].bar(numpy.arange(len(S)),X/float(N),color="orange",width=0.25,label="Mixed: "+str(N)+" models")

ax[1].set_xlim(-0.5,len(S)+0.5)
ax[1].set_ylim(0,1.2)

ax[1].set_xticks(range(len(S)))
ax[1].set_xticklabels(["s"+str(i) for i in range(len(S))],rotation=45)
for i in range(len(S)):
    ax[1].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[1].set_ylabel("Probability",fontsize=20)
    
for i in range(len(S)):
    ax[1].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

ax[1].set_title("KIH-atom types : cWzaY373C docked models",fontsize=25)
ax[1].legend(loc='best')

plt.show()
# Out:
# <div id='6d159dd3-23b5-4ee2-b051-396341b41d6e'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e06a5f19514a> in <module>()
#       5 X = numpy.zeros(len(S))
#       6 N = 0
# ----> 7 for pdb in list(Hbonds_stats_sample.keys()):
#       8     x = Hbonds_stats_sample[pdb]
#       9     X = X + numpy.asarray(x)
#
# NameError: name 'Hbonds_stats_sample' is not defined

# %% [markdown]
# <h1 style="text-align:center">Sampling by conductance and BB-assembly radius</h1>

# %% [markdown]
# Functions for data filtering

# %%
def rm_none(data):
    return [x for x in data if x!='None']

# %%
def filter_missing_data(data):
    x,y = data
    N = len(data[0])
    X = []; Y = []
    for n in range(N):
        try:
            a = x[n]
        except:
            a = 'None'
        try:
            b = y[n]
        except:
            b = 'None'
        if (a != 'None') and (b != 'None'):
            X.append(float(a))
            Y.append(float(b))
    return [X,Y]

# %%
from scipy.stats import gaussian_kde

def density_estimation(m1,m2):
    xmin=min(m1)
    xmax=max(m1)
    ymin=min(m2)
    ymax=max(m2)
    X, Y = numpy.mgrid[xmin:xmax:400j, ymin:ymax:400j]                                                     
    positions = numpy.vstack([X.ravel(), Y.ravel()])                                                       
    values = numpy.vstack([m1, m2])                                                                        
    kernel = gaussian_kde(values)                                                                 
    Z = numpy.reshape(kernel(positions).T, X.shape)
    return X,Y,Z

# %%
def weights4hist(data):
    return numpy.ones_like(data)/float(len(data))

# %% [markdown]
# Stuff for database data extraction

# %%
new_module = "/home/ba13026/mpmodeling/"
if new_module not in sys.path:
    sys.path.append(new_module)

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from setup_db import Json, Pdb, SuperHelix_Parameters, Conformation, BUDE_Energies \
,RosettaMP_Energies, Interhelix_Interactions, HOLE_Output, SASA_Estimates, Base

# %%
dbfile = path0+'/'+'refined1.db'

# %%
engine = create_engine('sqlite:///'+dbfile)
Base.metadata.bind = engine
DBSession = sessionmaker()
DBSession.bind = engine
session = DBSession()

# %% [markdown]
# **Get HOLE data from previously generated database**

# %%
model_ids = []
for i in range(1000):
    mid = session.query(Pdb.id).filter_by(
        pdb_name='input/refined1_0001_INPUT_'+str(format(i+1,'04d'))+'_ignorechain.pdb' ).first()
    model_ids.append(mid[0])

Gpred_Rmin_all = []
for id in model_ids:
    try:
        model_Gpred_Rmin = session.query(HOLE_Output.Gpred_Rmin).filter_by(id = id).one()
        Gpred_Rmin_all.append(model_Gpred_Rmin[0])
    except:
        Gpred_Rmin_all.append(-1)

# %% [markdown]
# Get **contour plot** data for $r_{BB}$ and `estimated conductance` ...

# %%
# X,Y = filter_missing_data([r_bb_data,Gpred_Rmin_all])
X,Y = r_bb_data,Gpred_Rmin_all
datacontour = list(density_estimation(X,Y))

XX,YY,ZZ = datacontour

# %% [markdown]
# **Clustering analysis**

# %%
from sklearn.cluster import KMeans
XY = numpy.array([r_bb_data, Gpred_Rmin_all]).T
kmeans = KMeans(n_clusters=2, random_state=0).fit(XY)
# kmeans.labels_
kmeans.cluster_centers_
# Out:
# array([[ 16.5503015 ,   1.05304009],
#        [ 14.15295213,   1.08919396]])

# %% [markdown]
# **Gaussian mixture fitting for datasets**

# %%
from sklearn.mixture import GMM
import pandas as pd

# %%
G_hist, ax1 = plt.subplots(1,2,figsize=(13,6))

model_name = "cWzaY373C"
##############################################################
ax1[0].hist(Gpred_Rmin_all,bins=70,normed=True,label="Docked "+model_name,alpha=0.5)

indata = Gpred_Rmin_all
n_modes = 4
gmm = GMM(n_components=n_modes)
gmm = gmm.fit(X=numpy.expand_dims(indata,1))
gmm_x = numpy.linspace(numpy.asarray(indata).min(),numpy.asarray(indata).max(),256)
data = gmm.score_samples(gmm_x.reshape(-1,1))
gmm_y = numpy.exp(data[0])

ax1[0].plot(gmm_x, gmm_y, color="green", lw=3, label="GMM")
####################################################### PANDAS STUFF
a = gmm.means_.reshape(-1)
b = gmm.weights_.reshape(-1)
c = gmm.covars_.reshape(-1)
stats_gmm = sorted(numpy.array([a,b,c]).T, key=lambda x:x[0], reverse=False)
units = "nS"
data_types = ["$\mu$","$\sigma$","Amplitude"]
modes_labels = ["Mode "+str(i) for i in range(n_modes)]
df_g_pred = pd.DataFrame(stats_gmm,index=modes_labels,columns=data_types)
##############################################################
ax1[0].set_xlabel("estimated conductance [nS]",fontsize="15")
ax1[0].set_ylabel("Absolute frequency",fontsize=15)
# ax1[0].set_ylim(0,100)
##############################################################
ax1[1].hist(r_bb_data,bins=70,color="red",normed=True,alpha=0.5)

indata = r_bb_data
n_modes = 2
gmm = GMM(n_components=n_modes)
gmm = gmm.fit(X=numpy.expand_dims(indata,1))
gmm_x = numpy.linspace(numpy.asarray(indata).min(),numpy.asarray(indata).max(),256)
data = gmm.score_samples(gmm_x.reshape(-1,1))
gmm_y = numpy.exp(data[0])

ax1[1].plot(gmm_x, gmm_y, color="green", lw=3, label="GMM")
####################################################### PANDAS STUFF
a = gmm.means_.reshape(-1)
b = gmm.weights_.reshape(-1)
c = gmm.covars_.reshape(-1)
stats_gmm = sorted(numpy.array([a,b,c]).T, key=lambda x:x[0], reverse=False)
n_modes = 2
units = "nS"
data_types = ["$\mu$","$\sigma$","Amplitude"]
modes_labels = ["Mode "+str(i) for i in range(n_modes)]
df_r_bb = pd.DataFrame(stats_gmm,index=modes_labels,columns=data_types)
##############################################################
ax1[1].set_xlabel("BB-Assembly radius [$\AA$]",fontsize=15)

ax1[0].legend(loc="best")
#################################################################
cmaps, ax2 = plt.subplots(1,2,figsize=(13,6))

ax2[0].scatter(X,Y,color="black",alpha=0.25)
ax2[0].contour(XX,YY,ZZ,30,linewidths=2)
#################################################################
ax2[0].set_xlim(13,19)
ax2[0].set_ylim(0,2.5)
ax2[0].set_xlabel("BB-Assembly radius [$\AA$]",fontsize=15)
ax2[0].set_ylabel("estimated conductance [nS]",fontsize=15)
#################################################################
from matplotlib import colors
cmap = colors.ListedColormap(['green','red'])

ax2[1].scatter(X,Y,color=cmap(list(kmeans.labels_)))
for x in kmeans.cluster_centers_:
    ax2[1].scatter(x[0],x[1],color="blue",s=20)
#################################################################
ax2[1].set_xlim(13,19)
ax2[1].set_ylim(0,2.5)
ax2[1].set_xlabel("BB-Assembly radius [$\AA$]",fontsize=15)
#################################################################
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# **Estimated conductance stats**

# %%
df_g_pred
# Out:
#            $\mu$  $\sigma$  Amplitude
# Mode 0  0.826328  0.457735   0.006710
# Mode 1  1.112904  0.376434   0.027741
# Mode 2  1.408567  0.099744   0.227990
# Mode 3  2.028567  0.066087   0.013379

# %% [markdown]
# **Backbone Assembly radius stats**

# %%
df_r_bb
# Out:
#            $\mu$  $\sigma$  Amplitude
# Mode 0  14.15001  0.515433   0.081361
# Mode 1  16.54568  0.484567   0.197463

# %% [markdown]
# <h1 style="text-align:center">Model sampling</h1>

# %% [markdown]
# **Identify remaining narrow/wide models**

# %%
# Parameters for filtering
g_m = 0.826328; g_std = 0.457735
r0_m = 14.15001; r0_std = 0.515433
r1_m = 16.54568; r1_std = 0.484567
fg = 1; fr = 1
# Lists of narrow/wide models
models_narrow_bb = []
models_wide_bb = []

for i in range(1000):
    g = Gpred_Rmin_all[i]
    if g != -1:
        if abs(g - g_m) <= fg*g_std:
            if abs(r_bb_data[i] - r0_m) <= fr*r0_std:
                models_narrow_bb.append(format(i+1,'04d'))
            elif abs(r_bb_data[i] - r1_m) <= fr*r1_std:
                models_wide_bb.append(format(i+1,'04d'))

# %%
print("Number of narrow models (G ~ 1st mode): ", len(models_narrow_bb))
print("Number of wide models (G ~ 1st mode): ", len(models_wide_bb))
# Out:
# Number of narrow models (G ~ 1st mode):  373
# Number of wide models (G ~ 1st mode):  301

# %% [markdown]
# All narrow and wide models

# %%
pdbs_all = {}
for model_type in ['narrow','wide']:
    pdbs_all[model_type] = []
    if model_type == 'narrow':
        pdb_modeln = models_narrow_bb
    elif model_type == 'wide':
        pdb_modeln = models_wide_bb
    for nmodel in pdb_modeln:
        pdbs_all[model_type].append("refined1_0001_INPUT_"+nmodel+"_ignorechain.pdb")

# %%
from operator import itemgetter

# %%
fig_check = plt.figure()

model_name = "cWzaY373C"
plt.scatter(r_bb_data, Gpred_Rmin_all,color='black',alpha=0.2)

colors = ['red','green']
c=0
for model_type in ['narrow','wide']:
    if model_type == 'narrow':
        models = models_narrow_bb
    elif model_type == 'wide':
        models = models_wide_bb
    indeces = [int(idx)-1 for idx in models]
    X = list(itemgetter(*indeces)(r_bb_data))
    Y = list(itemgetter(*indeces)(Gpred_Rmin_all))
    plt.scatter(X,Y,color=colors[c],s=30,alpha=0.5,label=model_type+' group :'+str(len(models))+' models')
    c+=1

plt.title(model_name+": sampled models: Mode 1",fontsize=20)
plt.xlabel("BB-Assembly radius [$\AA$]",fontsize=15)
plt.ylabel("estimated conductance [nS]",fontsize=15)
plt.ylim(0.5,2.5)

plt.legend(loc='best')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Sidechain Interaction analysis after group sepation

# %%
fig_hb_sample, ax = plt.subplots(2,1,figsize=(12,12))
model_name="cWzaY373C"
################################################################
S = S_hbonds_ordered
########################################################################
X = numpy.zeros(len(S))
N = 0
for pdb in models_narrow_bb:
    x = Hbonds_stats_sample[pdb]
    X = X + numpy.asarray(x)
    N += 1
        
ax[0].bar(numpy.arange(len(S)),X/float(N),color="red",width=0.25,label="Narrow: "+str(N)+" models")

X = numpy.zeros(len(S))
N = 0
for pdb in models_wide_bb:
    x = Hbonds_stats_sample[pdb]
    X = X + numpy.asarray(x)
    N += 1

ax[0].bar(numpy.arange(len(S))+0.25,X/float(N),color="green",width=0.25,label="Wide: "+str(N)+" models")
########################################################################


ax[0].set_xlim(-0.5,len(S)+0.5)
ax[0].set_ylim(0,1.2)

ax[0].set_xticks(range(len(S)))
ax[0].set_xticklabels(["s"+str(i) for i in range(len(S))],rotation=45)
for i in range(len(S)):
    ax[0].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[0].set_ylabel("Probability",fontsize=20)
    
for i in range(len(S)):
    ax[0].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

ax[0].set_title("H-bonds HO-atoms : "+model_name+" docked models",fontsize=25)
ax[0].legend(loc='best')
################################################################
S = S_kihs_ordered
########################################################################
X = numpy.zeros(len(S))
N = 0
for pdb in models_narrow_bb:
    x = KIHs_stats_sample[pdb]
    X = X + numpy.asarray(x)
    N += 1

ax[1].bar(numpy.arange(len(S)),X/float(N),color="red",width=0.25,label="Narrow: "+str(N)+" models")

X = numpy.zeros(len(S))
N = 0
for pdb in models_wide_bb:
    x = KIHs_stats_sample[pdb]
    X = X + numpy.asarray(x)
    N += 1

ax[1].bar(numpy.arange(len(S))+0.25,X/float(N),color="green",width=0.25,label="Wide: "+str(N)+" models")

########################################################################
ax[1].set_xlim(-0.5,len(S)+0.5)
ax[1].set_ylim(0,1.2)

ax[1].set_xticks(range(len(S)))
ax[1].set_xticklabels(["s"+str(i) for i in range(len(S))],rotation=45)
for i in range(len(S)):
    ax[1].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[1].set_ylabel("Probability",fontsize=20)
    
for i in range(len(S)):
    ax[1].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

ax[1].set_title("KIH-atom types : "+model_name+"docked models",fontsize=25)
ax[1].legend(loc='best')

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Embedding and EM of all models

# %%
import subprocess

# %%
directory = path0+'/md_relax/narrow'
if not os.path.isdir(directory):
    subprocess.call(['mkdir',directory])
    
directory = path0+'/md_relax/narrow/input'
if not os.path.isdir(directory):
    subprocess.call(['mkdir',directory])    

directory = path0+'/md_relax/narrow/output'
if not os.path.isdir(directory):
    subprocess.call(['mkdir',directory])
#############################################    
directory = path0+'/md_relax/wide'
if not os.path.isdir(directory):
    subprocess.call(['mkdir',directory])
    
directory = path0+'/md_relax/wide/input'
if not os.path.isdir(directory):
    subprocess.call(['mkdir',directory])    

directory = path0+'/md_relax/wide/output'
if not os.path.isdir(directory):
    subprocess.call(['mkdir',directory])

# %% [markdown]
# Copy all sample models to `input` subfolder in the corresponding group folder.

# %%
path0 = '/projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis'

# %%
for group in ['narrow','wide']:
    if group == 'narrow':
        models_bb = models_narrow_bb
    elif group == 'wide':
        models_bb = models_wide_bb
    for modeln in models_bb:
        pdbname = 'refined1_0001_INPUT_'+str(modeln)+'_ignorechain'
        pdb_path = path0+'input_trimmed/'+pdbname+'.pdb'
        destiny = path0+'md_relax/'+group+'/input/'
        subprocess.call(['cp',pdb_path,destiny])

# %% [raw]
# # Can also use these lines to renumber chains from input folder
#
# for group in ['narrow','wide']:
#     if group == 'narrow':
#         models_bb = models_narrow_bb
#     elif group == 'wide':
#         models_bb = models_wide_bb
#     for modeln in models_bb:
#         pdbname = 'refined1_0001_INPUT_'+str(modeln)+'_ignorechain'
#         pdb_path = path0+'/input/'+pdbname+'.pdb'
#         destiny = path0+'/md_relax/'+group+'/input/'+pdbname+'.pdb'
#         !pymol -qc ~/mpmodeling/tools/renumber_chains.py -- $pdb_path $destiny

# %%
models_narrow_bb = []
models_wide_bb = []
for group in ['narrow','wide']:
    lines = open(path0+'/md_relax/'+group+'_pdbs.txt','r').readlines()
    if group == 'narrow':
        models_bb = models_narrow_bb
    elif group == 'wide':
        models_bb = models_wide_bb
    for l in lines:
        models_bb.append(l.split("_")[3])

# %% [markdown]
# #### 1. Extract all post-EM protein PDBs

# %%
# Working directory path
path0="/projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax"
import os
counter = 0
for group in ['narrow','wide']:
    # Define list of model numbers per group
    if group == 'narrow':
        models_bb = models_narrow_bb
    elif group == 'wide':
        models_bb = models_wide_bb
    for modeln in models_bb:
        pdbname = 'refined1_0001_INPUT_'+str(modeln)+'_ignorechain'
        gro_path = path0+'/'+group+'/output/'+pdbname+'/complex/em/em_20000stps.gro'
        if not os.path.isfile(gro_path):
            print(group, pdbname)
            counter += 1
print("%s models couldn't be energy minimized."%counter)
print("Total number of models: ",len(models_narrow_bb)+len(models_wide_bb))
print("EM efficiency: ",1-counter/(len(models_narrow_bb)+len(models_wide_bb)))
# Out:
# narrow refined1_0001_INPUT_0005_ignorechain
# narrow refined1_0001_INPUT_0047_ignorechain
# narrow refined1_0001_INPUT_0078_ignorechain
# narrow refined1_0001_INPUT_0092_ignorechain
# narrow refined1_0001_INPUT_0109_ignorechain
# narrow refined1_0001_INPUT_0131_ignorechain
# narrow refined1_0001_INPUT_0142_ignorechain
# narrow refined1_0001_INPUT_0177_ignorechain
# narrow refined1_0001_INPUT_0215_ignorechain
# narrow refined1_0001_INPUT_0236_ignorechain
# narrow refined1_0001_INPUT_0249_ignorechain
# narrow refined1_0001_INPUT_0345_ignorechain
# narrow refined1_0001_INPUT_0352_ignorechain
# narrow refined1_0001_INPUT_0368_ignorechain
# narrow refined1_0001_INPUT_0420_ignorechain
# narrow refined1_0001_INPUT_0433_ignorechain
# narrow refined1_0001_INPUT_0483_ignorechain
# narrow refined1_0001_INPUT_0511_ignorechain
# narrow refined1_0001_INPUT_0518_ignorechain
# narrow refined1_0001_INPUT_0525_ignorechain
# narrow refined1_0001_INPUT_0559_ignorechain
# narrow refined1_0001_INPUT_0566_ignorechain
# narrow refined1_0001_INPUT_0592_ignorechain
# narrow refined1_0001_INPUT_0650_ignorechain
# narrow refined1_0001_INPUT_0651_ignorechain
# narrow refined1_0001_INPUT_0657_ignorechain
# narrow refined1_0001_INPUT_0682_ignorechain
# narrow refined1_0001_INPUT_0751_ignorechain
# narrow refined1_0001_INPUT_0829_ignorechain
# narrow refined1_0001_INPUT_0837_ignorechain
# narrow refined1_0001_INPUT_0842_ignorechain
# narrow refined1_0001_INPUT_0859_ignorechain
# narrow refined1_0001_INPUT_0864_ignorechain
# narrow refined1_0001_INPUT_0916_ignorechain
# narrow refined1_0001_INPUT_0921_ignorechain
# narrow refined1_0001_INPUT_0931_ignorechain
# narrow refined1_0001_INPUT_0963_ignorechain
# narrow refined1_0001_INPUT_0965_ignorechain
# narrow refined1_0001_INPUT_0985_ignorechain
# narrow refined1_0001_INPUT_0988_ignorechain
# narrow refined1_0001_INPUT_0993_ignorechain
# wide refined1_0001_INPUT_0061_ignorechain
# wide refined1_0001_INPUT_0145_ignorechain
# wide refined1_0001_INPUT_0169_ignorechain
# wide refined1_0001_INPUT_0185_ignorechain
# wide refined1_0001_INPUT_0251_ignorechain
# wide refined1_0001_INPUT_0281_ignorechain
# wide refined1_0001_INPUT_0374_ignorechain
# wide refined1_0001_INPUT_0736_ignorechain
# 49 models couldn't be energy minimized.
# Total number of models:  674
# EM efficiency:  0.9272997032640949

# %% [markdown]
# Extract protein structures for EM models

# %%
path0
# Out:
# '/projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax'

# %%
# Working directory path

import os
counter = 0
for group in ['narrow','wide']:
    # Define list of model numbers per group
    if group == 'narrow':
        models_bb = models_narrow_bb
    elif group == 'wide':
        models_bb = models_wide_bb
    for modeln in models_bb:
        pdbname = 'refined1_0001_INPUT_'+str(modeln)+'_ignorechain'
        gro_path = path0+'/'+group+'/output/'+pdbname+'/complex/em/em_20000stps'
#         if os.path.isfile(gro_path+'.gro') and not os.path.isfile(gro_path+'_Protein.pdb'):
        if os.path.isfile(gro_path+'.gro'):
            # !bash ~/mpmodeling/protocols/sem/gro2pdb.sh {gro_path}.gro
# Out:
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   502      Other residues
# There are: 28114      Water residues
# There are:  1994        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 116656 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 112440 atoms
#  12 Other               : 26104 atoms
#  13 POPC                : 26104 atoms
#  14 K                   :   989 atoms
#  15 CL                  :  1005 atoms
#  16 Water               : 84342 atoms
#  17 SOL                 : 84342 atoms
#  18 non-Water           : 32314 atoms
#  19 Ion                 :  1994 atoms
#  20 POPC                : 26104 atoms
#  21 K                   :   989 atoms
#  22 CL                  :  1005 atoms
#  23 Water_and_ions      : 86336 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#117: "And You Will Know That My Name is the Lord When I Lay My Vengeance Upon Thee." (Pulp Fiction)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 116656 atoms
# Volume: 1641.87 nm^3, corresponds to roughly 738800 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 116656 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 112440 elements
# Group    12 (          Other) has 26104 elements
# Group    13 (           POPC) has 26104 elements
# Group    14 (              K) has   989 elements
# Group    15 (             CL) has  1005 elements
# Group    16 (          Water) has 84342 elements
# Group    17 (            SOL) has 84342 elements
# Group    18 (      non-Water) has 32314 elements
# Group    19 (            Ion) has  1994 elements
# Group    20 (           POPC) has 26104 elements
# Group    21 (              K) has   989 elements
# Group    22 (             CL) has  1005 elements
# Group    23 ( Water_and_ions) has 86336 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0002_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#371: "England's dancing days are done" (P. J. Harvey)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   502      Other residues
# There are: 28102      Water residues
# There are:  1992        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 116618 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 112402 atoms
#  12 Other               : 26104 atoms
#  13 POPC                : 26104 atoms
#  14 K                   :   988 atoms
#  15 CL                  :  1004 atoms
#  16 Water               : 84306 atoms
#  17 SOL                 : 84306 atoms
#  18 non-Water           : 32312 atoms
#  19 Ion                 :  1992 atoms
#  20 POPC                : 26104 atoms
#  21 K                   :   988 atoms
#  22 CL                  :  1004 atoms
#  23 Water_and_ions      : 86298 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#157: "The Microsecond is Within Reach" (P.J. Van Maaren)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 116618 atoms
# Volume: 1640.22 nm^3, corresponds to roughly 738000 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 116618 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 112402 elements
# Group    12 (          Other) has 26104 elements
# Group    13 (           POPC) has 26104 elements
# Group    14 (              K) has   988 elements
# Group    15 (             CL) has  1004 elements
# Group    16 (          Water) has 84306 elements
# Group    17 (            SOL) has 84306 elements
# Group    18 (      non-Water) has 32312 elements
# Group    19 (            Ion) has  1992 elements
# Group    20 (           POPC) has 26104 elements
# Group    21 (              K) has   988 elements
# Group    22 (             CL) has  1004 elements
# Group    23 ( Water_and_ions) has 86298 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0004_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#411: "You see it through a charmed medium: you can not discern that the gilding is slime and the silk draperies cobwebs; that the marble is sordid slate, and the polished woods mere refuse chips and scale bark." (Mr. Rochester in Jane Eyre by Charlotte Bronte)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   502      Other residues
# There are: 28087      Water residues
# There are:  1992        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 116573 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 112357 atoms
#  12 Other               : 26104 atoms
#  13 POPC                : 26104 atoms
#  14 K                   :   988 atoms
#  15 CL                  :  1004 atoms
#  16 Water               : 84261 atoms
#  17 SOL                 : 84261 atoms
#  18 non-Water           : 32312 atoms
#  19 Ion                 :  1992 atoms
#  20 POPC                : 26104 atoms
#  21 K                   :   988 atoms
#  22 CL                  :  1004 atoms
#  23 Water_and_ions      : 86253 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#392: "Strength is just an accident arising from the weakness of others" (Joseph Conrad)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 116573 atoms
# Volume: 1640.19 nm^3, corresponds to roughly 738000 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 116573 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 112357 elements
# Group    12 (          Other) has 26104 elements
# Group    13 (           POPC) has 26104 elements
# Group    14 (              K) has   988 elements
# Group    15 (             CL) has  1004 elements
# Group    16 (          Water) has 84261 elements
# Group    17 (            SOL) has 84261 elements
# Group    18 (      non-Water) has 32312 elements
# Group    19 (            Ion) has  1992 elements
# Group    20 (           POPC) has 26104 elements
# Group    21 (              K) has   988 elements
# Group    22 (             CL) has  1004 elements
# Group    23 ( Water_and_ions) has 86253 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0008_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#182: "It is Lunchtime" (A.R. Van Buuren)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   502      Other residues
# There are: 28006      Water residues
# There are:  1990        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 116328 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 112112 atoms
#  12 Other               : 26104 atoms
#  13 POPC                : 26104 atoms
#  14 K                   :   987 atoms
#  15 CL                  :  1003 atoms
#  16 Water               : 84018 atoms
#  17 SOL                 : 84018 atoms
#  18 non-Water           : 32310 atoms
#  19 Ion                 :  1990 atoms
#  20 POPC                : 26104 atoms
#  21 K                   :   987 atoms
#  22 CL                  :  1003 atoms
#  23 Water_and_ions      : 86008 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#356: "He's using code that only you and I know" (Kate Bush)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 116328 atoms
# Volume: 1639.55 nm^3, corresponds to roughly 737700 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 116328 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 112112 elements
# Group    12 (          Other) has 26104 elements
# Group    13 (           POPC) has 26104 elements
# Group    14 (              K) has   987 elements
# Group    15 (             CL) has  1003 elements
# Group    16 (          Water) has 84018 elements
# Group    17 (            SOL) has 84018 elements
# Group    18 (      non-Water) has 32310 elements
# Group    19 (            Ion) has  1990 elements
# Group    20 (           POPC) has 26104 elements
# Group    21 (              K) has   987 elements
# Group    22 (             CL) has  1003 elements
# Group    23 ( Water_and_ions) has 86008 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0010_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#141: "Carry Me Away" (Motors)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   502      Other residues
# There are: 28080      Water residues
# There are:  1988        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 116548 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 112332 atoms
#  12 Other               : 26104 atoms
#  13 POPC                : 26104 atoms
#  14 K                   :   986 atoms
#  15 CL                  :  1002 atoms
#  16 Water               : 84240 atoms
#  17 SOL                 : 84240 atoms
#  18 non-Water           : 32308 atoms
#  19 Ion                 :  1988 atoms
#  20 POPC                : 26104 atoms
#  21 K                   :   986 atoms
#  22 CL                  :  1002 atoms
#  23 Water_and_ions      : 86228 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#104: "Count the Bubbles In Your Hair" (The Breeders)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 116548 atoms
# Volume: 1637.57 nm^3, corresponds to roughly 736900 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 116548 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 112332 elements
# Group    12 (          Other) has 26104 elements
# Group    13 (           POPC) has 26104 elements
# Group    14 (              K) has   986 elements
# Group    15 (             CL) has  1002 elements
# Group    16 (          Water) has 84240 elements
# Group    17 (            SOL) has 84240 elements
# Group    18 (      non-Water) has 32308 elements
# Group    19 (            Ion) has  1988 elements
# Group    20 (           POPC) has 26104 elements
# Group    21 (              K) has   986 elements
# Group    22 (             CL) has  1002 elements
# Group    23 ( Water_and_ions) has 86228 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0014_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#255: "I'm Looking for a New Simulation" (Stone Temple Pilots)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   502      Other residues
# There are: 28073      Water residues
# There are:  1990        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 116529 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 112313 atoms
#  12 Other               : 26104 atoms
#  13 POPC                : 26104 atoms
#  14 K                   :   987 atoms
#  15 CL                  :  1003 atoms
#  16 Water               : 84219 atoms
#  17 SOL                 : 84219 atoms
#  18 non-Water           : 32310 atoms
#  19 Ion                 :  1990 atoms
#  20 POPC                : 26104 atoms
#  21 K                   :   987 atoms
#  22 CL                  :  1003 atoms
#  23 Water_and_ions      : 86209 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#28: "No One Could Foresee the End That Came So Fast" (Slayer)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 116529 atoms
# Volume: 1639.4 nm^3, corresponds to roughly 737700 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 116529 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 112313 elements
# Group    12 (          Other) has 26104 elements
# Group    13 (           POPC) has 26104 elements
# Group    14 (              K) has   987 elements
# Group    15 (             CL) has  1003 elements
# Group    16 (          Water) has 84219 elements
# Group    17 (            SOL) has 84219 elements
# Group    18 (      non-Water) has 32310 elements
# Group    19 (            Ion) has  1990 elements
# Group    20 (           POPC) has 26104 elements
# Group    21 (              K) has   987 elements
# Group    22 (             CL) has  1003 elements
# Group    23 ( Water_and_ions) has 86209 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/narrow/output/refined1_0001_INPUT_0017_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#152: "BioBeat is Not Available In Regular Shops" (P.J. Meulenhoff)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
# ...
# Group    21 (              K) has   993 elements
# Group    22 (             CL) has  1009 elements
# Group    23 ( Water_and_ions) has 87541 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0997_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0997_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#97: "I Should Be the Pimp Of the Year" (Urban Dance Squad)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   502      Other residues
# There are: 28599      Water residues
# There are:  2004        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 118121 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 113905 atoms
#  12 Other               : 26104 atoms
#  13 POPC                : 26104 atoms
#  14 K                   :   994 atoms
#  15 CL                  :  1010 atoms
#  16 Water               : 85797 atoms
#  17 SOL                 : 85797 atoms
#  18 non-Water           : 32324 atoms
#  19 Ion                 :  2004 atoms
#  20 POPC                : 26104 atoms
#  21 K                   :   994 atoms
#  22 CL                  :  1010 atoms
#  23 Water_and_ions      : 87801 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#321: "The Feeling of Power was Intoxicating, Magic" (Frida Hyvonen)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 118121 atoms
# Volume: 1650.17 nm^3, corresponds to roughly 742500 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 118121 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 113905 elements
# Group    12 (          Other) has 26104 elements
# Group    13 (           POPC) has 26104 elements
# Group    14 (              K) has   994 elements
# Group    15 (             CL) has  1010 elements
# Group    16 (          Water) has 85797 elements
# Group    17 (            SOL) has 85797 elements
# Group    18 (      non-Water) has 32324 elements
# Group    19 (            Ion) has  2004 elements
# Group    20 (           POPC) has 26104 elements
# Group    21 (              K) has   994 elements
# Group    22 (             CL) has  1010 elements
# Group    23 ( Water_and_ions) has 87801 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0998_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#155: "I Am a Wonderful Thing" (Kid Creole)
#
# GROMACS:    gmx make_ndx, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi make_ndx -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/em_20000stps.gro -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/em_20000stps.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   256    Protein residues
# There are:   503      Other residues
# There are: 28509      Water residues
# There are:  2006        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 117905 atoms
#   1 Protein             :  4216 atoms
#   2 Protein-H           :  2032 atoms
#   3 C-alpha             :   256 atoms
#   4 Backbone            :   768 atoms
#   5 MainChain           :  1032 atoms
#   6 MainChain+Cb        :  1280 atoms
#   7 MainChain+H         :  1288 atoms
#   8 SideChain           :  2928 atoms
#   9 SideChain-H         :  1000 atoms
#  10 Prot-Masses         :  4216 atoms
#  11 non-Protein         : 113689 atoms
#  12 Other               : 26156 atoms
#  13 POPC                : 26156 atoms
#  14 K                   :   995 atoms
#  15 CL                  :  1011 atoms
#  16 Water               : 85527 atoms
#  17 SOL                 : 85527 atoms
#  18 non-Water           : 32378 atoms
#  19 Ion                 :  2006 atoms
#  20 POPC                : 26156 atoms
#  21 K                   :   995 atoms
#  22 CL                  :  1011 atoms
#  23 Water_and_ions      : 87533 atoms
#
#  nr : group       !   'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom        &   'del' nr         'splitres' nr   'l': list residues
#  't': atom type   |   'keep' nr        'splitat' nr    'h': help
#  'r': residue         'res' nr         'chain' char
#  "name": group        'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/em_20000stps.ndx to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/#em_20000stps.ndx.1#
#
# gcq#398: "The soul? There's nothing but chemistry here" (Breaking Bad)
#
# GROMACS:    gmx editconf, VERSION 5.0.6
#
# GROMACS is written by:
# Emile Apol         Rossen Apostolov   Herman J.C. Berendsen Par Bjelkmar
# Aldert van Buuren  Rudi van Drunen    Anton Feenstra     Sebastian Fritsch
# Gerrit Groenhof    Christoph Junghans Peter Kasson       Carsten Kutzner
# Per Larsson        Justin A. Lemkul   Magnus Lundborg    Pieter Meulenhoff
# Erik Marklund      Teemu Murtola      Szilard Pall       Sander Pronk
# Roland Schulz      Alexey Shvetsov    Michael Shirts     Alfons Sijbers
# Peter Tieleman     Christian Wennberg Maarten Wolf
# and the project leaders:
# Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2014, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, VERSION 5.0.6
# Executable:   /cm/shared/apps/Gromacs-5.0.6/install_gcc/bin/gmx_mpi
# Library dir:  /cm/shared/apps/Gromacs-5.0.6/install_gcc/share/gromacs/top
# Command line:
#   gmx_mpi editconf -f /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/em_20000stps.gro -n /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/em_20000stps.ndx -o /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/em_20000stps.pdb -label A
#
# Read 117905 atoms
# Volume: 1651.96 nm^3, corresponds to roughly 743300 electrons
# No velocities found
#
# Select a group for output:
# Group     0 (         System) has 117905 elements
# Group     1 (        Protein) has  4216 elements
# Group     2 (      Protein-H) has  2032 elements
# Group     3 (        C-alpha) has   256 elements
# Group     4 (       Backbone) has   768 elements
# Group     5 (      MainChain) has  1032 elements
# Group     6 (   MainChain+Cb) has  1280 elements
# Group     7 (    MainChain+H) has  1288 elements
# Group     8 (      SideChain) has  2928 elements
# Group     9 (    SideChain-H) has  1000 elements
# Group    10 (    Prot-Masses) has  4216 elements
# Group    11 (    non-Protein) has 113689 elements
# Group    12 (          Other) has 26156 elements
# Group    13 (           POPC) has 26156 elements
# Group    14 (              K) has   995 elements
# Group    15 (             CL) has  1011 elements
# Group    16 (          Water) has 85527 elements
# Group    17 (            SOL) has 85527 elements
# Group    18 (      non-Water) has 32378 elements
# Group    19 (            Ion) has  2006 elements
# Group    20 (           POPC) has 26156 elements
# Group    21 (              K) has   995 elements
# Group    22 (             CL) has  1011 elements
# Group    23 ( Water_and_ions) has 87533 elements
# Select a group: Selected 1: 'Protein'
#
# Back Off! I just backed up /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/em_20000stps.pdb to /projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax/wide/output/refined1_0001_INPUT_0999_ignorechain/complex/em/#em_20000stps.pdb.1#
#
# gcq#26: "Art For Arts Sake, Money For Gods Sake" (10 CC)

# %%
path0
# Out:
# '/projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzay373c_NoWPN/3-analysis/md_relax'

# %%
# Working directory path

import os
counter = 0
for group in ['narrow','wide']:
    # Define list of model numbers per group
    if group == 'narrow':
        models_bb = models_narrow_bb
    elif group == 'wide':
        models_bb = models_wide_bb
    for modeln in models_bb:
        pdbname = 'refined1_0001_INPUT_'+str(modeln)+'_ignorechain'
        gro_path = path0+'/'+group+'/output/'+pdbname+'/complex/em/em_20000stps'
        if os.path.isfile(gro_path+'.gro') and not os.path.isfile(gro_path+'_Protein.pdb'):
            print(group, pdbname)
            counter += 1
print("%s Post-EM protein structures have not been extracted."%counter)
# Out:
# 0 Post-EM protein structures have not been extracted.

# %%
# Extract of post-EM protein PDBs (No-PR, Unconstrained bonds)
postEM_ppdbs = {}
for group in ['narrow','wide']:
    # Define list of model numbers per group
    if group == 'narrow':
        models_bb = models_narrow_bb
    elif group == 'wide':
        models_bb = models_wide_bb
    postEM_ppdbs[group] = {}
    for modeln in models_bb:
        pdbname = 'refined1_0001_INPUT_'+str(modeln)+'_ignorechain'
        ppdb_path = path0+'/'+group+'/output/'+pdbname+'/complex/em/em_20000stps_Protein.pdb'
        if os.path.isfile(ppdb_path):
            postEM_ppdbs[group][pdbname] = ppdb_path
        else:
            postEM_ppdbs[group][pdbname] = 'NoFile'

# %% [markdown]
# #### 2. Find all H-bonds and KIHs: original and post-EM models, for narrow and wide models

# %%
from insert2db_interactions import get_OH_atoms
from insert2db_interactions import get_KIHs
from insert2db_interactions import interaction_direction
import json

# %%
def find_interactions(pdb):
    hbonds_data = [json.loads(hb) for hb in get_OH_atoms(pdb)]
    pdb_hbonds = [json.dumps(hb[:-1]+[hb[-1]]) for hb in hbonds_data]
    # KIHs data
    kihs_data = [json.loads(kih) for kih in get_KIHs(pdb)]
    pdb_kihs = [json.dumps(kih[:-1]+[kih[-1]]) for kih in kihs_data]
    return pdb_hbonds, pdb_kihs

# %%
Hbonds_data = {}
KIHs_data = {}
for group in ["narrow", "wide"]:
    # Define pdbname space and paths to post-EM pdbs
    pdbnames = list(postEM_ppdbs[group].keys())
    Hbonds_data[group] = {}
    KIHs_data[group] = {}
    for pdb in pdbnames:
        Hbonds_data[group][pdb] = {}
        KIHs_data[group][pdb] = {}
        # Find interactions for originally docked model
        pdb_original = path0+"/"+group+"/input/"+pdb+".pdb"
        pdb_hbonds, pdb_kihs = find_interactions(pdb_original)
        # Find interactions for post-EM docked model
        pdb_postEM = postEM_ppdbs[group][pdb]
        if pdb_postEM != 'NoFile':
            hbonds_postEM, kihs_postEM = find_interactions(pdb_postEM)
            # Store data in dic
            Hbonds_data[group][pdb] = {"original":pdb_hbonds, "em":hbonds_postEM}
            KIHs_data[group][pdb] = {"original":pdb_kihs, "em":kihs_postEM}
        else:
            Hbonds_data[group][pdb] = {"original":pdb_hbonds, "em":"NoFile"}
            KIHs_data[group][pdb] = {"original":pdb_kihs, "em":"NoFile"}

# %%
with open(path0+'/'+'Hbonds_Original_PostEM.json', 'w') as fp:
    json.dump(Hbonds_data, fp)

# %%
with open(path0+'/'+'KIHs_Original_PostEM.json', 'w') as fp:
    json.dump(KIHs_data, fp)

# %% [markdown]
# <span style="color:red">MAKE DATABASE OF BB-RAD, HOLE G, HBONDS AND KIHS</span>

# %% [markdown]
# #### 3. Find base sets of OH-atom types and KIHs
#
# Get all H-bonds and KIHs identities, then reduce by defining their direction in the assembly.

# %%
S_hbonds = set()
for group in ["wide","narrow"]:
    for pdb in list(Hbonds_data[group].keys()):
        data0 = Hbonds_data[group][pdb]
        for type in ["original","em"]:
            data1 = data0[type]
            if data1 != "NoFile":
                S_hbonds = S_hbonds.union(set(data1))

# %%
S_kihs = set()
for group in ["wide","narrow"]:
    for pdb in list(KIHs_data[group].keys()):
        data0 = KIHs_data[group][pdb]
        for type in ["original","em"]:
            data1 = data0[type]
            if data1 != "NoFile":
                S_kihs = S_kihs.union(set(data1))

# %%
S_hbonds = set([json.dumps(x[:-1]+[interaction_direction(x[-1])]) for x in [json.loads(x) for x in list(S_hbonds)]])
S_kihs = set([json.dumps(x[:-1]+[interaction_direction(x[-1])]) for x in [json.loads(x) for x in list(S_kihs)]])

# %%
S_hbonds_ordered = []
for resn in range(1,33):
    for hb in S_hbonds:
        x = json.loads(hb)
        if int(x[0]) == resn:
            S_hbonds_ordered.append(json.dumps(x))

# %%
S_kihs_ordered = []
for resn in range(1,33):
    for kih in S_kihs:
        x = json.loads(kih)
        if int(x[0]) == resn:
            S_kihs_ordered.append(json.dumps(x))

# %%
S_hbonds = S_hbonds_ordered
S_kihs = S_kihs_ordered

# %%
S_hbonds_ordered
# Out:
# ['["1", "H2", "5", "NH1", 0]',
#  '["1", "H2", "5", "NH2", 0]',
#  '["6", "HE1", "12", "OE1", -1]',
#  '["6", "HE1", "5", "NH2", 0]',
#  '["11", "HG", "12", "OE1", -1]',
#  '["11", "HG", "7", "OD1", 0]',
#  '["11", "HG", "12", "NE2", 0]',
#  '["11", "HG", "12", "OE1", 0]',
#  '["16", "HG1", "7", "OD1", 1]',
#  '["16", "HG1", "7", "ND2", 1]',
#  '["18", "HG1", "22", "OD1", -1]',
#  '["18", "HG1", "22", "OD2", -1]',
#  '["18", "HG1", "21", "ND1", 0]',
#  '["21", "HE2", "22", "OD2", -1]',
#  '["21", "HE2", "28", "NH2", -1]',
#  '["21", "HD1", "22", "OD2", 0]',
#  '["21", "HE2", "26", "OG1", -1]',
#  '["21", "HD1", "26", "OG1", -1]',
#  '["21", "HD1", "24", "OG1", 0]',
#  '["21", "HD1", "25", "OE1", 0]',
#  '["21", "HD1", "25", "OE2", 0]',
#  '["21", "HD1", "22", "OD1", 0]',
#  '["21", "HE2", "25", "OE1", 0]',
#  '["21", "HE2", "25", "OE2", 0]',
#  '["21", "HE2", "29", "SG", -1]',
#  '["21", "HD1", "22", "OD2", -1]',
#  '["24", "HG1", "29", "SG", -1]',
#  '["24", "HG1", "28", "NH1", 0]',
#  '["24", "HG1", "26", "OG1", -1]',
#  '["24", "HG1", "22", "OD1", -1]',
#  '["24", "HG1", "25", "OE2", 0]',
#  '["26", "HG1", "28", "NH1", 1]',
#  '["26", "HG1", "21", "NE2", 1]',
#  '["26", "HG1", "21", "ND1", 1]',
#  '["26", "HG1", "25", "OE2", 1]',
#  '["26", "HG1", "25", "OE1", 1]',
#  '["28", "HE", "29", "SG", 0]',
#  '["28", "HE", "25", "OE1", 0]',
#  '["28", "HE", "25", "OE1", -1]',
#  '["28", "HE", "26", "OG1", -1]',
#  '["28", "HE", "25", "OE2", 0]',
#  '["28", "HE", "24", "OG1", 0]',
#  '["28", "HE", "29", "SG", -1]',
#  '["29", "HG", "25", "OE2", 1]',
#  '["29", "HG", "25", "OE2", 0]',
#  '["29", "HG", "28", "NH2", 0]',
#  '["29", "HG", "32", "OG1", 0]',
#  '["29", "HG", "21", "NE2", 1]',
#  '["29", "HG", "28", "NH1", 0]',
#  '["29", "HG", "28", "NH1", 1]',
#  '["29", "HG", "25", "OE1", 0]',
#  '["29", "HG", "25", "OE1", 1]',
#  '["29", "HG", "24", "OG1", 1]',
#  '["29", "HG", "28", "NH2", 1]',
#  '["29", "HG", "32", "OG1", 1]',
#  '["31", "HZ2", "28", "NH2", 0]',
#  '["31", "HZ2", "28", "NH1", 0]',
#  '["31", "HZ2", "25", "OE2", 0]',
#  '["32", "HG1", "29", "SG", 0]']

# %%
S_kihs_ordered
# Out:
# ['["3", "9", "12", "13", "16", -1]',
#  '["3", "13", "16", "17", "20", -1]',
#  '["3", "12", "13", "15", "16", -1]',
#  '["4", "9", "12", "13", "16", -1]',
#  '["7", "12", "13", "16", "9", -1]',
#  '["7", "9", "12", "13", "16", -1]',
#  '["7", "12", "13", "15", "16", -1]',
#  '["9", "1", "4", "3", "2", 1]',
#  '["9", "1", "3", "4", "2", 1]',
#  '["9", "1", "2", "3", "4", 1]',
#  '["9", "1", "3", "2", "4", 1]',
#  '["9", "1", "4", "3", "7", 1]',
#  '["9", "3", "1", "4", "7", 1]',
#  '["9", "3", "1", "7", "4", 1]',
#  '["9", "4", "1", "3", "7", 1]',
#  '["9", "3", "1", "4", "2", 1]',
#  '["9", "1", "3", "4", "7", 1]',
#  '["10", "16", "19", "20", "23", -1]',
#  '["12", "1", "2", "3", "6", 1]',
#  '["12", "7", "4", "3", "11", 1]',
#  '["12", "3", "4", "7", "11", 1]',
#  '["12", "1", "3", "4", "7", 1]',
#  '["13", "1", "2", "3", "4", 1]',
#  '["13", "1", "3", "4", "7", 1]',
#  '["13", "3", "6", "7", "10", 1]',
#  '["14", "15", "16", "19", "20", -1]',
#  '["14", "15", "16", "18", "19", -1]',
#  '["14", "18", "19", "22", "23", -1]',
#  '["14", "16", "19", "20", "23", -1]',
#  '["15", "7", "11", "14", "15", 1]',
#  '["15", "3", "6", "7", "10", 1]',
#  '["15", "7", "10", "11", "14", 1]',
#  '["16", "7", "10", "14", "17", 1]',
#  '["16", "14", "11", "7", "15", 1]',
#  '["16", "10", "3", "7", "6", 1]',
#  '["16", "10", "7", "3", "6", 1]',
#  '["16", "10", "11", "14", "15", 1]',
#  '["16", "7", "3", "10", "6", 1]',
#  '["16", "3", "6", "7", "10", 1]',
#  '["16", "7", "14", "10", "11", 1]',
#  '["16", "10", "6", "7", "14", 1]',
#  '["16", "3", "4", "7", "10", 1]',
#  '["16", "3", "6", "10", "14", 1]',
#  '["16", "3", "7", "10", "14", 1]',
#  '["16", "10", "3", "7", "14", 1]',
#  '["16", "6", "7", "10", "14", 1]',
#  '["16", "7", "10", "14", "3", 1]',
#  '["16", "7", "10", "3", "11", 1]',
#  '["16", "10", "3", "6", "7", 1]',
#  '["16", "7", "10", "14", "11", 1]',
#  '["16", "3", "7", "10", "6", 1]',
#  '["16", "7", "3", "10", "11", 1]',
#  '["16", "10", "7", "6", "14", 1]',
#  '["16", "10", "7", "14", "3", 1]',
#  '["16", "10", "7", "3", "11", 1]',
#  '["16", "3", "7", "10", "11", 1]',
#  '["16", "10", "3", "7", "4", 1]',
#  '["16", "3", "7", "10", "4", 1]',
#  '["16", "7", "10", "11", "14", 1]',
#  '["16", "7", "11", "14", "15", 1]',
#  '["16", "3", "10", "7", "11", 1]',
#  '["16", "7", "10", "3", "4", 1]',
#  '["16", "7", "3", "10", "4", 1]',
#  '["16", "7", "10", "3", "6", 1]',
#  '["16", "10", "3", "7", "11", 1]',
#  '["16", "3", "10", "7", "4", 1]',
#  '["16", "14", "11", "7", "10", 1]',
#  '["16", "10", "7", "14", "11", 1]',
#  '["16", "14", "10", "7", "11", 1]',
#  '["16", "10", "7", "3", "14", 1]',
#  '["16", "3", "10", "7", "6", 1]',
#  '["16", "10", "7", "14", "6", 1]',
#  '["16", "11", "7", "14", "15", 1]',
#  '["17", "19", "22", "23", "26", -1]',
#  '["19", "18", "14", "17", "15", 1]',
#  '["19", "18", "14", "21", "17", 1]',
#  '["19", "7", "10", "11", "14", 1]',
#  '["19", "14", "15", "18", "21", 1]',
#  '["19", "7", "10", "14", "17", 1]',
#  '["19", "10", "11", "14", "17", 1]',
#  '["19", "14", "15", "17", "18", 1]',
#  '["19", "10", "14", "17", "21", 1]',
#  '["19", "14", "10", "7", "17", 1]',
#  '["19", "14", "18", "21", "17", 1]',
#  '["19", "14", "17", "18", "21", 1]',
#  '["19", "14", "10", "11", "7", 1]',
#  '["19", "14", "18", "17", "21", 1]',
#  '["21", "23", "19", "26", "20", -1]',
#  '["21", "19", "20", "23", "26", -1]',
#  '["21", "23", "22", "26", "20", -1]',
#  '["21", "22", "25", "26", "29", -1]',
#  '["21", "23", "19", "22", "20", -1]',
#  '["21", "26", "29", "22", "25", -1]',
#  '["21", "22", "23", "20", "26", -1]',
#  '["21", "26", "29", "25", "22", -1]',
#  '["21", "23", "22", "19", "26", -1]',
#  '["21", "23", "19", "22", "26", -1]',
#  '["21", "29", "26", "25", "28", -1]',
#  '["21", "23", "26", "22", "19", -1]',
#  '["21", "23", "19", "26", "22", -1]',
#  '["21", "26", "29", "22", "28", -1]',
#  '["21", "23", "22", "26", "19", -1]',
#  '["21", "23", "19", "20", "22", -1]',
#  '["21", "29", "26", "22", "25", -1]',
#  '["21", "20", "22", "23", "26", -1]',
#  '["21", "23", "22", "19", "20", -1]',
#  '["21", "23", "19", "20", "26", -1]',
#  '["21", "25", "26", "28", "29", -1]',
#  '["21", "26", "29", "28", "25", -1]',
#  '["21", "19", "22", "23", "26", -1]',
#  '["21", "26", "29", "25", "28", -1]',
#  '["21", "19", "20", "22", "23", -1]',
#  '["22", "14", "17", "18", "21", 1]',
#  '["22", "18", "21", "22", "25", 1]',
#  '["23", "21", "24", "25", "28", 1]',
#  '["23", "14", "17", "18", "21", 1]',
#  '["23", "10", "13", "14", "17", 1]',
#  '["23", "21", "18", "14", "17", 1]',
#  '["23", "18", "21", "22", "25", 1]',
#  '["25", "22", "25", "26", "29", -1]',
#  '["26", "22", "24", "25", "28", 1]',
#  '["26", "17", "20", "21", "24", 1]',
#  '["26", "21", "17", "20", "18", 1]',
#  '["26", "17", "18", "20", "21", 1]',
#  '["26", "21", "17", "24", "20", 1]',
#  '["26", "24", "27", "28", "31", 1]',
#  '["26", "17", "21", "24", "25", 1]',
#  '["26", "21", "24", "25", "28", 1]',
#  '["28", "23", "26", "27", "30", -1]',
#  '["28", "22", "25", "26", "29", -1]',
#  '["28", "29", "26", "30", "28", -1]',
#  '["28", "26", "29", "30", "32", -1]',
#  '["28", "25", "26", "28", "29", -1]',
#  '["28", "29", "26", "25", "30", -1]',
#  '["28", "29", "26", "25", "28", -1]',
#  '["28", "26", "30", "27", "29", -1]',
#  '["28", "26", "28", "29", "30", -1]',
#  '["28", "26", "27", "29", "30", -1]',
#  '["28", "29", "26", "30", "25", -1]',
#  '["28", "25", "26", "29", "30", -1]',
#  '["29", "25", "28", "29", "32", 1]',
#  '["29", "28", "29", "31", "32", 1]',
#  '["29", "24", "28", "25", "27", 1]',
#  '["29", "24", "25", "28", "21", 1]',
#  '["29", "25", "24", "27", "28", 1]',
#  '["29", "21", "24", "25", "28", 1]',
#  '["29", "24", "25", "28", "27", 1]',
#  '["29", "24", "25", "27", "28", 1]',
#  '["29", "25", "28", "24", "31", 1]',
#  '["29", "28", "25", "27", "24", 1]',
#  '["29", "24", "27", "28", "31", 1]',
#  '["29", "24", "27", "28", "25", 1]',
#  '["29", "25", "24", "28", "27", 1]',
#  '["29", "24", "25", "28", "31", 1]']

# %% [markdown]
# #### 4. Find average interaction multiplicity per conformation group

# %%
Hbonds_stats = {}

for group in ["narrow","wide"]:
    pdbnames = list(postEM_ppdbs[group].keys())
    Hbonds_stats[group] = {}
    for pdb in pdbnames:
        Hbonds_stats[group][pdb] = {}
        hbonds_model = Hbonds_data[group][pdb]
        if hbonds_model["em"] != "NoFile":
            for model_type in ["original","em"]:
                shb_vector = []
                for shb in S_hbonds:
                    c = 0
                    for x in hbonds_model[model_type]:
                        hb_raw = json.loads(x)
                        hb = json.dumps(hb_raw[:-1]+[interaction_direction(hb_raw[-1])])
                        if hb == shb:
                            c+=1
                    shb_vector.append(c)
                Hbonds_stats[group][pdb][model_type] = shb_vector    
        else:
            for model_type in ["original","em"]:
                Hbonds_stats[group][pdb][model_type] = "NA"

# %%
fig_hb_new, ax = plt.subplots(2,1,figsize=(16,12))

################################################################
X = numpy.zeros(len(S_hbonds))
Y = numpy.zeros(len(S_hbonds))
N_models = 0
for pdb in list(Hbonds_stats["narrow"].keys()):
    x = Hbonds_stats["narrow"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["original"])
        Y = Y + numpy.asarray(x["em"])
        N_models += 1

ax[0].bar(numpy.arange(len(S_hbonds))+0.25,X/float(8*N_models),color="blue",width=0.25,label="Original: "+str(N_narrow)+" models")
ax[0].bar(numpy.arange(len(S_hbonds)),Y/float(8*N_models),color="red",width=0.25,label="post-EM: "+str(N_narrow)+" models")

ax[0].set_xlim(-0.5,len(S_hbonds)+0.5)
ax[0].set_ylim(0,1.2)

ax[0].set_xticks(range(len(S_hbonds)))
ax[0].set_xticklabels(["s"+str(i) for i in range(len(S_hbonds))],rotation=45)
for i in range(len(S_hbonds)):
    ax[0].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[0].set_ylabel("Probability",fontsize=20)
    
for i in range(len(S_hbonds)):
    ax[0].text(i-0.25,0.8,list(S_hbonds)[i],fontsize=10,rotation=90)

ax[0].set_title("H-bonds HO-atoms : cWza narrow",fontsize=25)
################################################################
X = numpy.zeros(len(S_hbonds))
Y = numpy.zeros(len(S_hbonds))
N_models = 0
for pdb in list(Hbonds_stats["wide"].keys()):
    x = Hbonds_stats["wide"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["original"])
        Y = Y + numpy.asarray(x["em"])
        N_models += 1

ax[1].bar(numpy.arange(len(S_hbonds))+0.25,X/float(8*N_models),color="blue",width=0.25,label="Original: "+str(N_wide)+" models")
ax[1].bar(numpy.arange(len(S_hbonds)),Y/float(8*N_models),color="red",width=0.25,label="post-EM: "+str(N_wide)+" models")

ax[1].set_xlim(-0.5,len(S_hbonds)+0.5)
ax[1].set_ylim(0,1.2)

ax[1].set_xlabel("HO-pair type",fontsize=20)
ax[1].set_xticks(range(len(S_hbonds)))
ax[1].set_xticklabels(["s"+str(i) for i in range(len(S_hbonds))],rotation=45)
for i in range(len(S_hbonds)):
    ax[1].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[1].set_ylabel("Probability",fontsize=20)

for i in range(len(S_hbonds)):
    ax[1].text(i-0.25,0.8,list(S_hbonds)[i],fontsize=10,rotation=90)

ax[1].set_title("H-bonds HO-atoms : cWzaY373C wide",fontsize=25)
################################################################

ax[0].legend(loc="upper center")
ax[1].legend(loc="upper center")
plt.show()
# Out:
# <div id='7067d754-207f-4ca4-b08b-8d9288fc28f9'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-30f53baca8a4> in <module>()
#      12         N_models += 1
#      13
# ---> 14 ax[0].bar(numpy.arange(len(S_hbonds))+0.25,X/float(8*N_models),color="blue",width=0.25,label="Original: "+str(N_narrow)+" models")
#      15 ax[0].bar(numpy.arange(len(S_hbonds)),Y/float(8*N_models),color="red",width=0.25,label="post-EM: "+str(N_narrow)+" models")
#      16
#
# NameError: name 'N_narrow' is not defined

# %%
fig_hb_comparison_new, ax = plt.subplots(2,1,figsize=(16,12))

################################################################
X = numpy.zeros(len(S_hbonds))
N_narrow = 0
for pdb in list(Hbonds_stats["narrow"].keys()):
    x = Hbonds_stats["narrow"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["original"])
        N_narrow += 1

Y = numpy.zeros(len(S_hbonds))
N_wide = 0
for pdb in list(Hbonds_stats["wide"].keys()):
    x = Hbonds_stats["wide"][pdb]
    if x["em"]!="NA":
        Y = Y + numpy.asarray(x["original"])
        N_wide += 1
        
ax[0].bar(numpy.arange(len(S_hbonds))+0.25,X/float(8*N_narrow),color="red",width=0.25,label="Original: Narrow: "+str(N_narrow)+" models")
ax[0].bar(numpy.arange(len(S_hbonds)),Y/float(8*N_wide),color="green",width=0.25,label="Original: Wide: "+str(N_wide)+" models")

ax[0].set_xlim(-0.5,len(S_hbonds)+0.5)
ax[0].set_ylim(0,1.2)

ax[0].set_xticks(range(len(S_hbonds)))
ax[0].set_xticklabels(["s"+str(i) for i in range(len(S_hbonds))],rotation=45)
for i in range(len(S_hbonds)):
    ax[0].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[0].set_ylabel("Probability",fontsize=20)
    
for i in range(len(S_hbonds)):
    ax[0].text(i-0.25,0.8,list(S_hbonds)[i],fontsize=10,rotation=90)

ax[0].set_title("H-bonds HO-atoms : cWza",fontsize=25)
################################################################
X = numpy.zeros(len(S_hbonds))
N_narrow = 0
for pdb in list(Hbonds_stats["narrow"].keys()):
    x = Hbonds_stats["narrow"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["em"])
        N_narrow += 1

Y = numpy.zeros(len(S_hbonds))
N_wide = 0
for pdb in list(Hbonds_stats["wide"].keys()):
    x = Hbonds_stats["wide"][pdb]
    if x["em"]!="NA":
        Y = Y + numpy.asarray(x["em"])
        N_wide += 1

ax[1].bar(numpy.arange(len(S_hbonds))+0.25,X/float(8*N_narrow),color="red",width=0.25,label="post-EM: Narrow: "+str(N_narrow)+" models")
ax[1].bar(numpy.arange(len(S_hbonds)),Y/float(8*N_wide),color="green",width=0.25,label="post-EM: Wide: "+str(N_wide)+" models")

ax[1].set_xlim(-0.5,len(S_hbonds)+0.5)
ax[1].set_ylim(0,1.2)

ax[1].set_xlabel("HO-pair type",fontsize=20)
ax[1].set_xticks(range(len(S_hbonds)))
ax[1].set_xticklabels(["s"+str(i) for i in range(len(S_hbonds))],rotation=45)
for i in range(len(S_hbonds)):
    ax[1].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[1].set_ylabel("Probability",fontsize=20)

for i in range(len(S_hbonds)):
    ax[1].text(i-0.25,0.8,list(S_hbonds)[i],fontsize=10,rotation=90)

################################################################

ax[0].legend(loc="upper center")
ax[1].legend(loc="upper center")
plt.show()

# %% [markdown]
# KIHs

# %%
KIHs_stats = {}

for group in ["narrow","wide"]:
    pdbnames = list(postEM_ppdbs[group].keys())
    KIHs_stats[group] = {}
    for pdb in pdbnames:
        KIHs_stats[group][pdb] = {}
        kihs_model = KIHs_data[group][pdb]
        if kihs_model["em"] != "NoFile":
            for model_type in ["original","em"]:
                skih_vector = []
                for skih in S_kihs:
                    c = 0
                    for x in kihs_model[model_type]:
                        kih_raw = json.loads(x)
                        kih = json.dumps(kih_raw[:-1]+[interaction_direction(kih_raw[-1])])
                        if kih == skih:
                            c+=1
                    skih_vector.append(c)
                KIHs_stats[group][pdb][model_type] = skih_vector    
        else:
            for model_type in ["original","em"]:
                KIHs_stats[group][pdb][model_type] = "NA"

# %%
fig_kih_original_new, ax = plt.subplots(2,1,figsize=(22,12))
################################################################
S = S_kihs
X = numpy.zeros(len(S))
Y = numpy.zeros(len(S))
N_models = 0
for pdb in list(KIHs_stats["narrow"].keys()):
    x = KIHs_stats["narrow"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["original"])
        Y = Y + numpy.asarray(x["em"])
        N_models += 1
        
ax[0].bar(numpy.arange(len(S))+0.25,X/float(8*N_models),color="blue",width=0.25,label="Original: "+str(N_models)+" models")
ax[0].bar(numpy.arange(len(S)),Y/float(8*N_models),color="red",width=0.25,label="post-EM: "+str(N_models)+" models")

ax[0].set_xlim(-0.5,len(S)+0.5)
ax[0].set_ylim(0,1.2)

ax[0].set_xticks(range(len(S_kihs)))
ax[0].set_xticklabels(["s"+str(i) for i in range(len(S_kihs))],rotation=45)
for i in range(len(S_kihs)):
    ax[0].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[0].set_ylabel("Probability",fontsize=20)

for i in range(len(S)):
    ax[0].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

ax[0].set_title("KIH atom groups : cWza narrow",fontsize=25)
################################################################
X = numpy.zeros(len(S))
Y = numpy.zeros(len(S))
N_models = 0
for pdb in list(KIHs_stats["wide"].keys()):
    x = KIHs_stats["wide"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["original"])
        Y = Y + numpy.asarray(x["em"])
        N_models += 1
        
ax[1].bar(numpy.arange(len(S))+0.25,X/float(8*N_models),color="blue",width=0.25,label="Original: "+str(N_models)+" models")
ax[1].bar(numpy.arange(len(S)),Y/float(8*N_models),color="red",width=0.25,label="post-EM: "+str(N_models)+" models")

ax[1].set_xlim(-0.5,len(S)+0.5)
ax[1].set_ylim(0,1.2)

ax[1].set_xlabel("KIH type",fontsize=20)
ax[1].set_xticks(range(len(S_kihs)))
ax[1].set_xticklabels(["s"+str(i) for i in range(len(S_kihs))],rotation=45)
for i in range(len(S_kihs)):
    ax[1].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[1].set_ylabel("Probability",fontsize=20)

for i in range(len(S)):
    ax[1].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

ax[1].set_title("KIH atom groups : cWza wide",fontsize=25)
################################################################

ax[0].legend(loc="upper center")
ax[1].legend(loc="upper center")
plt.show()

# %%
fig_kih_original_new, ax = plt.subplots(2,1,figsize=(22,12))
################################################################
S = S_kihs
X = numpy.zeros(len(S))
N_narrow = 0
for pdb in list(KIHs_stats["narrow"].keys()):
    x = KIHs_stats["narrow"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["original"])
        N_narrow += 1

Y = numpy.zeros(len(S))
N_wide = 0
for pdb in list(KIHs_stats["wide"].keys()):
    x = KIHs_stats["wide"][pdb]
    if x["em"]!="NA":
        Y = Y + numpy.asarray(x["original"])
        N_wide += 1
        
ax[0].bar(numpy.arange(len(S))+0.25,X/float(8*N_narrow),color="red",width=0.25,label="Original: Narrow: "+str(N_narrow)+" models")
ax[0].bar(numpy.arange(len(S)),Y/float(8*N_wide),color="green",width=0.25,label="Original: Wide: "+str(N_wide)+" models")

ax[0].set_xlim(-0.5,len(S)+0.5)
ax[0].set_ylim(0,1.2)

ax[0].set_xticks(range(len(S_kihs)))
ax[0].set_xticklabels(["s"+str(i) for i in range(len(S_kihs))],rotation=45)
for i in range(len(S_kihs)):
    ax[0].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[0].set_ylabel("Probability",fontsize=20)

for i in range(len(S)):
    ax[0].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

ax[0].set_title("KIH atom groups : cWza",fontsize=25)
################################################################
X = numpy.zeros(len(S))
N_narrow = 0
for pdb in list(KIHs_stats["narrow"].keys()):
    x = KIHs_stats["narrow"][pdb]
    if x["em"]!="NA":
        X = X + numpy.asarray(x["em"])
        N_narrow += 1

Y = numpy.zeros(len(S))
N_wide = 0
for pdb in list(KIHs_stats["wide"].keys()):
    x = KIHs_stats["wide"][pdb]
    if x["em"]!="NA":
        Y = Y + numpy.asarray(x["em"])
        N_wide += 1
        
ax[1].bar(numpy.arange(len(S))+0.25,X/float(8*N_models),color="red",width=0.25,label="post-EM: Narrow: "+str(N_narrow)+" models")
ax[1].bar(numpy.arange(len(S)),Y/float(8*N_models),color="green",width=0.25,label="post-EM: Wide: "+str(N_wide)+" models")

ax[1].set_xlim(-0.5,len(S)+0.5)
ax[1].set_ylim(0,1.2)

ax[1].set_xlabel("KIH type",fontsize=20)
ax[1].set_xticks(range(len(S_kihs)))
ax[1].set_xticklabels(["s"+str(i) for i in range(len(S_kihs))],rotation=45)
for i in range(len(S_kihs)):
    ax[1].plot((i,i),(0,1.2),color="black",linestyle="--",alpha=0.5)

ax[1].set_ylabel("Probability",fontsize=20)

for i in range(len(S)):
    ax[1].text(i-0.25,0.8,list(S)[i],fontsize=10,rotation=90)

################################################################

ax[0].legend(loc="upper center")
ax[1].legend(loc="upper center")
plt.show()

# %% [markdown]
# **To-do's**
#
# 1. Take screenshots of structures showing key H-bonds and KIHs that differentiate narrow and wide groups
#
# ... Setup DB for analysis (Go through previous scripts)
#
# 2. Repeat analysis for cWzaK375C
#
# 3. Submit PRMD cWza sims (PR-SC+BB) for MD (100ns), GPU ... Determine times and resources needed for simulation and analysis.
#
# 3. Make slides explaining overall protocol for analysis. Clean Jupyter notebooks
#
# 4. Write functions for analysis and order libraries in common location (~/mpmodeling/protocol/analysis or tools)

# %%
/projects/s21/ba13026/Wza_Modeling/L-structures/rosetta/bg_test/cwzak375c_NoWPN/3-analysis
